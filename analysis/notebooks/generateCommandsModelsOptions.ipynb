# %%
import itertools
from itertools import product
import numpy as np
import pandas as pd

# %%
def getCodeFromBinary(s):
    for i in range(len(s)):
        if s[i].isalpha():
            return getCodeFromBinary(s[:i] + '0' + s[i+1:]) + getCodeFromBinary(s[:i] + '1' + s[i+1:])
    return [int(s, 2)]

def getVarNames(listVars):
    return "_".join(["v" + str(v) for v in listVars])

# %%
def generateModelsDict(startIndex=0, numModels=10, nameOptionsFile = "/home/submit/pdmonte/CMSSW_10_6_27/src/Hrare2023/analysis/TMVA_regression/optionModels.out", centralValues=None):
    '''This function has to solve the following:
        - Create a model and append it to a dictionary
        - Save in a file the id of the model and the properties'''
    
    allModels = {}
    with open(nameOptionsFile, "a") as file:
        for i in range(numModels):
            modelOptions = getRandomOptions(centralValues=centralValues)
            allModels[startIndex + i] = getOptionsString(modelOptions)
            file.write(str(startIndex + i) + ' $ ' + ' $ '.join(modelOptions.values()) + "\n")

    return allModels
    

def getOptionsString(modelDict):
    outString = "\"!V"
    if modelDict["VarTransform"] != "":
        outString += ":VarTransform=" + modelDict["VarTransform"]
    outString += ":NTrees=" + modelDict["NTrees"]
    outString += ":BoostType=" + modelDict["BoostType"]
    outString += ":Shrinkage=" + modelDict["Shrinkage"]
    outString += ":MaxDepth=" + modelDict["MaxDepth"]
    outString += ":SeparationType=" + modelDict["SeparationType"]
    outString += ":nCuts=" + modelDict["nCuts"]
    outString += ":UseRandomisedTrees=" + modelDict["UseRandomisedTrees"]
    outString += ":UseNvars=" + modelDict["UseNvars"]
    outString += ":UseBaggedBoost=" + modelDict["UseBaggedBoost"]
    outString += ":BaggedSampleFraction=" + modelDict["BaggedSampleFraction"]
    outString += ":PruneMethod=" + modelDict["PruneMethod"]
    outString += ":PruneStrength=" + modelDict["PruneStrength"]
    outString += ":PruningValFraction=" + modelDict["PruningValFraction"]
    outString += "\""
    return outString


def getRandomOptions(centralValues=None):
    outOptions = {}
    if centralValues is None or len(centralValues) != 12:
        outOptions["VarTransform"] = getVarTransformChoice(maxSymbols=4)
        outOptions["NTrees"] = str(getRandomInt(1500, 5000))
        outOptions["BoostType"] = "Grad"
        outOptions["Shrinkage"] = str(getRandomFloat(0.10, 0.5))
        outOptions["MaxDepth"] = str(getRandomInt(5, 10))
        outOptions["SeparationType"] = "RegressionVariance"
        outOptions["nCuts"] = str(getRandomInt(15, 100))
        outOptions["UseRandomisedTrees"] = getRandomBool()
        outOptions["UseNvars"] = str(getRandomInt(2, 100))
        outOptions["UseBaggedBoost"] = getRandomBool()
        outOptions["BaggedSampleFraction"] = str(getRandomFloat(0.50, 5.00))
        outOptions["PruneMethod"] = getPruneMethodChoice()
        outOptions["PruneStrength"] = str(getRandomInt(0, 100))
        outOptions["PruningValFraction"] = str(getRandomFloat(0.0, 2.0))
    else:
        outOptions["VarTransform"] = getVarTransformChoice(maxSymbols=4, meanSigma=centralValues[0])
        outOptions["NTrees"] = str(getRandomInt(1000, 5000, meanSigma=centralValues[1], spacing=100))
        outOptions["BoostType"] = "Grad"
        outOptions["Shrinkage"] = str(getRandomFloat(0.04, 0.5, meanSigma=centralValues[2]))
        outOptions["MaxDepth"] = str(getRandomInt(4, 10, meanSigma=centralValues[3]))
        outOptions["SeparationType"] = "RegressionVariance"
        outOptions["nCuts"] = str(getRandomInt(10, 100, meanSigma=centralValues[4]))
        outOptions["UseRandomisedTrees"] = getRandomBool(meanSigma=centralValues[5])
        outOptions["UseNvars"] = str(getRandomInt(5, 100, meanSigma=centralValues[6]))
        outOptions["UseBaggedBoost"] = getRandomBool(meanSigma=centralValues[7])
        outOptions["BaggedSampleFraction"] = str(getRandomFloat(0.70, 5.00, meanSigma=centralValues[8]))
        outOptions["PruneMethod"] = getPruneMethodChoice(meanSigma=centralValues[9])
        outOptions["PruneStrength"] = str(getRandomInt(0, 100, meanSigma=centralValues[10]))
        outOptions["PruningValFraction"] = str(getRandomFloat(0.0, 2.0, meanSigma=centralValues[11]))
    return outOptions


def getVarTransformChoice(minSymbols=0, maxSymbols=2, meanSigma=None):
    # todo with sigma
    nTsf = np.random.randint(minSymbols, maxSymbols+1)
    varTransform = ["P", "G", "D", "N"]
    good = []
    initList = list(product(varTransform, repeat=nTsf))
    for e in initList:
        repeated = False
        for i in range(len(e)-1):
            if e[i] == e[i+1]:
                repeated = True
        if e.count("P") > 1:
            repeated = True
        if not repeated:
            good.append(",".join(e))
    if meanSigma is None:
        return np.random.choice(good)
    else:
        if np.random.uniform(0, 1) < meanSigma[1]:
            return meanSigma[0]
        else:
            return np.random.choice(good)


def getBestVarTransform(n=30):
    best = ["G", "N,G,N,G", "", "N", "P,N,D", "P,N,D,N", "P,G", "P,N", "P,D", "P", "N,G", "G,N", "G,N,G,N", "N,G,N", "G,N,G", "P,D,N", "P,D,N,D", "N,P,D", "N,P,N,D", "N,P,G", "P,D,G", "D,N,D", "P,G,N", "P,N,G", "D,N,G", "P,G,N,G", "D", "P,N,P,D"]
    return best[:n]


def getPruneMethodChoice(meanSigma=None):
    return getRandomItem(["NoPruning", "NoPruning", "ExpectedError", "CostComplexity"], meanSigma=meanSigma)


def getRandomInt(minNum = 0, maxNum=100, meanSigma=None, spacing=1):
    if meanSigma is None:
        return int(np.round(np.random.randint(minNum, maxNum+1)/spacing, 0)*spacing)
    else:
        num = np.random.normal(meanSigma[0], meanSigma[1])
        while num < minNum or num > maxNum:
            num = np.random.normal(meanSigma[0], meanSigma[1])
        return int(np.round(num/spacing, 0)*spacing)


def getRandomFloat(minNum = 0.0, maxNum=1.0, meanSigma=None):
    if meanSigma is None:
        return np.round(np.random.uniform(minNum, maxNum), 3)
    else:
        num = np.random.normal(meanSigma[0], meanSigma[1])
        while num < minNum or num > maxNum:
            num = np.random.normal(meanSigma[0], meanSigma[1])
        return np.round(num, 3)
    

def getRandomBool(meanSigma=None):
    return getRandomItem(["F", "T"], meanSigma=meanSigma)

        
def getRandomItem(listOfChoices, meanSigma=None):
    if meanSigma is None:
        return np.random.choice(listOfChoices)
    else:
        remainingChoices = [x for x in listOfChoices if x != meanSigma[0]]
        if np.random.uniform(0, 1) < meanSigma[1]:
            return meanSigma[0]
        else:
            return np.random.choice(remainingChoices)

def getInitValsModelOptions(modelsId, variances= [0.5, 600, 0.15, 2, 10, 0.7, 10, 0.7, 0.2, 0.6, 10, 0.3], fileName="/home/submit/pdmonte/CMSSW_10_6_27/src/Hrare2023/analysis/TMVA_regression/optionModels.out"):
    column_names = ['Id', 'VarTsf', 'NTrees', 'BoostType', 'Shrinkage', 'MaxDepth', 'SeparationType', 'nCuts', 'RndmTrees',
                    'UseNvars', 'UseBaggedBoost', 'BaggedSampleFraction', 'PruneMethod', 'PruneStrength', 'PruningValFraction']
    column_data_types = {'Id': int, 'VarTsf': str, 'NTrees': int, 'BoostType': str, 'Shrinkage': float, 'MaxDepth': int, 'SeparationType': str, 'nCuts': int, 'RndmTrees': str,
                    'UseNvars': int, 'UseBaggedBoost': str, 'BaggedSampleFraction': float, 'PruneMethod': str, 'PruneStrength': int, 'PruningValFraction': float}
    
    df = pd.read_csv(fileName, sep='$', names=column_names, dtype=column_data_types)
    df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
    df = df[df["Id"].isin(modelsId)]
    selected_columns = ['VarTsf', 'NTrees', 'Shrinkage', 'MaxDepth', 'nCuts', 'RndmTrees', 'UseNvars', 'UseBaggedBoost', 
                        'BaggedSampleFraction', 'PruneMethod', 'PruneStrength', 'PruningValFraction']
    list_of_lists = df[selected_columns].values.tolist()
    list_of_lists = [[[op, vr] for op, vr in zip(model, variances)] for model in list_of_lists]

    return list_of_lists

# %%
channel="d0starrho"
cat = "ggh"
f = open("commands_temp.txt", "a")
#comm = "RECO:::python computeErrors.py -m RECO -c {channel}".format(channel=channel)
#print(comm)
#f.write(comm + "\n")
dfC, dlC = 7, 3684

modelNames=["BDTG_df15_dl3684_v0_v1"] #13/3620 D3rho
#modelNames=["BDTG_df13_dl3620_v0_v1"] #13/3620 omega/phi
#modelNames=["BDTG_df7_dl3684_v0_v1"] #5/3620 D2

goodModels = [30000] #phi
goodModels = [30001] #omega
goodModels = [30002] #d0star
goodModels = [30003] #d0starrho
#goodModels = [30000, 30001, 30002, 30003]

#optionsDict = {0: "\"!V:NTrees=1000:BoostType=Grad:Shrinkage=0.2:MaxDepth=5:SeparationType=SDivSqrtSPlusB:nCuts=90:UseRandomisedTrees=T:UseNvars=67:UseBaggedBoost:BaggedSampleFraction=2.4:PruneMethod=NoPruning\""}

#initVals = [["G", 0.3], [2000, 200], [0.2, 0.001], [7, 1], [30, 1], ["F", 0.37], [30, 1], ["F", 0.15], [1.0, 1], ["NoPruning", 0.677], [50, 1], [1, 1]]

#initVals = getInitValsModelOptions(goodModels, variances = [0.5, 700, 0.07, 1.5, 10, 0.6, 8, 0.6, 0.25, 0.6, 8, 0.25], fileName="/home/submit/pdmonte/CMSSW_10_6_27/src/Hrare2023/analysis/TMVA_regression/optionModels.out")
initVals = getInitValsModelOptions(goodModels, variances = [0.7, 250, 0.04, 1.1, 8, 0.7, 7, 0.7, 0.20, 0.7, 7, 0.20], fileName="/home/submit/pdmonte/CMSSW_10_6_27/src/Hrare2023/analysis/TMVA_regression/optionModels.out")
#initVals = getInitValsModelOptions(goodModels, variances = [0.9999999, 0.000001, 0.000001, 0.000001, 0.000001, 0.9999999, 0.000001, 0.9999999, 0.000001, 0.9999999, 0.000001, 0.000001], fileName="/home/submit/pdmonte/CMSSW_10_6_27/src/Hrare2023/analysis/TMVA_regression/optionModels.out")

for k, init in enumerate(initVals):
    numMod = 500
    optionsDict = generateModelsDict(startIndex=51500+k*numMod, numModels=numMod, nameOptionsFile = "/home/submit/pdmonte/CMSSW_10_6_27/src/Hrare2023/analysis/TMVA_regression/optionModels.out", centralValues=init)
    #optionsDict = generateModelsDict(startIndex=2103, numModels=1200)

    for key, v in optionsDict.items():
        for line in modelNames:
            jobName = line.strip()
            dfC = jobName.split("_")[1].replace("df", "")
            dlC = jobName.split("_")[2].replace("dl", "")
            listVars = [int(x.replace("v", "")) for x in jobName.split("_")[3:]]
            varNamesShort = "".join([str(v) for v in listVars])
            comm = "o{idx}_v{varNamesShort}_{prodCat}:::root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}_opt{idx}\", \"{channel}\", \"{prodCat}\", 0, {{{listVars}}}, {dfC}, {dlC}, {optStr})' && root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}_opt{idx}\", \"{channel}\", \"{prodCat}\", 1, {{{listVars}}}, {dfC}, {dlC}, {optStr})' && root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}_opt{idx}\", \"{channel}\", \"{prodCat}\", 2, {{{listVars}}}, {dfC}, {dlC}, {optStr})' && python computeErrors.py -m BDTG_df{dfC}_dl{dlC}_{varNames}_opt{idx} -c {channel} -p {prodCat}".format(dfC=dfC, dlC=dlC, channel=channel, prodCat=cat, listVars=str(listVars)[1:-1], varNames=getVarNames(listVars), varNamesShort=varNamesShort, idx=key, optStr=v)
            print(comm)
            f.write(comm + "\n")
f.close()
# Out:
# o51500_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51500", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=2000:BoostType=Grad:Shrinkage=0.093:MaxDepth=5:SeparationType=RegressionVariance:nCuts=33:UseRandomisedTrees=T:UseNvars=63:UseBaggedBoost=T:BaggedSampleFraction=1.408:PruneMethod=CostComplexity:PruneStrength=26:PruningValFraction=0.815")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51500", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=2000:BoostType=Grad:Shrinkage=0.093:MaxDepth=5:SeparationType=RegressionVariance:nCuts=33:UseRandomisedTrees=T:UseNvars=63:UseBaggedBoost=T:BaggedSampleFraction=1.408:PruneMethod=CostComplexity:PruneStrength=26:PruningValFraction=0.815")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51500", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=2000:BoostType=Grad:Shrinkage=0.093:MaxDepth=5:SeparationType=RegressionVariance:nCuts=33:UseRandomisedTrees=T:UseNvars=63:UseBaggedBoost=T:BaggedSampleFraction=1.408:PruneMethod=CostComplexity:PruneStrength=26:PruningValFraction=0.815")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51500 -c d0starrho -p ggh
# o51501_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51501", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=2200:BoostType=Grad:Shrinkage=0.088:MaxDepth=4:SeparationType=RegressionVariance:nCuts=26:UseRandomisedTrees=F:UseNvars=71:UseBaggedBoost=T:BaggedSampleFraction=1.644:PruneMethod=NoPruning:PruneStrength=44:PruningValFraction=0.484")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51501", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=2200:BoostType=Grad:Shrinkage=0.088:MaxDepth=4:SeparationType=RegressionVariance:nCuts=26:UseRandomisedTrees=F:UseNvars=71:UseBaggedBoost=T:BaggedSampleFraction=1.644:PruneMethod=NoPruning:PruneStrength=44:PruningValFraction=0.484")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51501", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=2200:BoostType=Grad:Shrinkage=0.088:MaxDepth=4:SeparationType=RegressionVariance:nCuts=26:UseRandomisedTrees=F:UseNvars=71:UseBaggedBoost=T:BaggedSampleFraction=1.644:PruneMethod=NoPruning:PruneStrength=44:PruningValFraction=0.484")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51501 -c d0starrho -p ggh
# o51502_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51502", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1700:BoostType=Grad:Shrinkage=0.045:MaxDepth=4:SeparationType=RegressionVariance:nCuts=34:UseRandomisedTrees=F:UseNvars=92:UseBaggedBoost=T:BaggedSampleFraction=1.523:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.704")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51502", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1700:BoostType=Grad:Shrinkage=0.045:MaxDepth=4:SeparationType=RegressionVariance:nCuts=34:UseRandomisedTrees=F:UseNvars=92:UseBaggedBoost=T:BaggedSampleFraction=1.523:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.704")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51502", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1700:BoostType=Grad:Shrinkage=0.045:MaxDepth=4:SeparationType=RegressionVariance:nCuts=34:UseRandomisedTrees=F:UseNvars=92:UseBaggedBoost=T:BaggedSampleFraction=1.523:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.704")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51502 -c d0starrho -p ggh
# o51503_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51503", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.081:MaxDepth=5:SeparationType=RegressionVariance:nCuts=47:UseRandomisedTrees=F:UseNvars=72:UseBaggedBoost=T:BaggedSampleFraction=1.86:PruneMethod=NoPruning:PruneStrength=26:PruningValFraction=0.491")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51503", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.081:MaxDepth=5:SeparationType=RegressionVariance:nCuts=47:UseRandomisedTrees=F:UseNvars=72:UseBaggedBoost=T:BaggedSampleFraction=1.86:PruneMethod=NoPruning:PruneStrength=26:PruningValFraction=0.491")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51503", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.081:MaxDepth=5:SeparationType=RegressionVariance:nCuts=47:UseRandomisedTrees=F:UseNvars=72:UseBaggedBoost=T:BaggedSampleFraction=1.86:PruneMethod=NoPruning:PruneStrength=26:PruningValFraction=0.491")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51503 -c d0starrho -p ggh
# o51504_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51504", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=2000:BoostType=Grad:Shrinkage=0.131:MaxDepth=6:SeparationType=RegressionVariance:nCuts=18:UseRandomisedTrees=F:UseNvars=62:UseBaggedBoost=T:BaggedSampleFraction=1.714:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.363")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51504", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=2000:BoostType=Grad:Shrinkage=0.131:MaxDepth=6:SeparationType=RegressionVariance:nCuts=18:UseRandomisedTrees=F:UseNvars=62:UseBaggedBoost=T:BaggedSampleFraction=1.714:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.363")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51504", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=2000:BoostType=Grad:Shrinkage=0.131:MaxDepth=6:SeparationType=RegressionVariance:nCuts=18:UseRandomisedTrees=F:UseNvars=62:UseBaggedBoost=T:BaggedSampleFraction=1.714:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.363")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51504 -c d0starrho -p ggh
# o51505_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51505", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,P,G,N:NTrees=1700:BoostType=Grad:Shrinkage=0.137:MaxDepth=5:SeparationType=RegressionVariance:nCuts=16:UseRandomisedTrees=T:UseNvars=60:UseBaggedBoost=T:BaggedSampleFraction=1.391:PruneMethod=NoPruning:PruneStrength=26:PruningValFraction=0.507")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51505", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,P,G,N:NTrees=1700:BoostType=Grad:Shrinkage=0.137:MaxDepth=5:SeparationType=RegressionVariance:nCuts=16:UseRandomisedTrees=T:UseNvars=60:UseBaggedBoost=T:BaggedSampleFraction=1.391:PruneMethod=NoPruning:PruneStrength=26:PruningValFraction=0.507")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51505", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,P,G,N:NTrees=1700:BoostType=Grad:Shrinkage=0.137:MaxDepth=5:SeparationType=RegressionVariance:nCuts=16:UseRandomisedTrees=T:UseNvars=60:UseBaggedBoost=T:BaggedSampleFraction=1.391:PruneMethod=NoPruning:PruneStrength=26:PruningValFraction=0.507")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51505 -c d0starrho -p ggh
# o51506_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51506", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.18:MaxDepth=5:SeparationType=RegressionVariance:nCuts=46:UseRandomisedTrees=T:UseNvars=74:UseBaggedBoost=T:BaggedSampleFraction=1.944:PruneMethod=CostComplexity:PruneStrength=33:PruningValFraction=0.992")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51506", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.18:MaxDepth=5:SeparationType=RegressionVariance:nCuts=46:UseRandomisedTrees=T:UseNvars=74:UseBaggedBoost=T:BaggedSampleFraction=1.944:PruneMethod=CostComplexity:PruneStrength=33:PruningValFraction=0.992")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51506", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.18:MaxDepth=5:SeparationType=RegressionVariance:nCuts=46:UseRandomisedTrees=T:UseNvars=74:UseBaggedBoost=T:BaggedSampleFraction=1.944:PruneMethod=CostComplexity:PruneStrength=33:PruningValFraction=0.992")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51506 -c d0starrho -p ggh
# o51507_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51507", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.127:MaxDepth=6:SeparationType=RegressionVariance:nCuts=40:UseRandomisedTrees=T:UseNvars=62:UseBaggedBoost=T:BaggedSampleFraction=1.528:PruneMethod=ExpectedError:PruneStrength=28:PruningValFraction=0.685")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51507", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.127:MaxDepth=6:SeparationType=RegressionVariance:nCuts=40:UseRandomisedTrees=T:UseNvars=62:UseBaggedBoost=T:BaggedSampleFraction=1.528:PruneMethod=ExpectedError:PruneStrength=28:PruningValFraction=0.685")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51507", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.127:MaxDepth=6:SeparationType=RegressionVariance:nCuts=40:UseRandomisedTrees=T:UseNvars=62:UseBaggedBoost=T:BaggedSampleFraction=1.528:PruneMethod=ExpectedError:PruneStrength=28:PruningValFraction=0.685")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51507 -c d0starrho -p ggh
# o51508_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51508", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.101:MaxDepth=5:SeparationType=RegressionVariance:nCuts=31:UseRandomisedTrees=F:UseNvars=67:UseBaggedBoost=T:BaggedSampleFraction=1.449:PruneMethod=ExpectedError:PruneStrength=27:PruningValFraction=0.334")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51508", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.101:MaxDepth=5:SeparationType=RegressionVariance:nCuts=31:UseRandomisedTrees=F:UseNvars=67:UseBaggedBoost=T:BaggedSampleFraction=1.449:PruneMethod=ExpectedError:PruneStrength=27:PruningValFraction=0.334")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51508", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.101:MaxDepth=5:SeparationType=RegressionVariance:nCuts=31:UseRandomisedTrees=F:UseNvars=67:UseBaggedBoost=T:BaggedSampleFraction=1.449:PruneMethod=ExpectedError:PruneStrength=27:PruningValFraction=0.334")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51508 -c d0starrho -p ggh
# o51509_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51509", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.167:MaxDepth=6:SeparationType=RegressionVariance:nCuts=36:UseRandomisedTrees=F:UseNvars=75:UseBaggedBoost=T:BaggedSampleFraction=1.233:PruneMethod=NoPruning:PruneStrength=16:PruningValFraction=0.892")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51509", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.167:MaxDepth=6:SeparationType=RegressionVariance:nCuts=36:UseRandomisedTrees=F:UseNvars=75:UseBaggedBoost=T:BaggedSampleFraction=1.233:PruneMethod=NoPruning:PruneStrength=16:PruningValFraction=0.892")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51509", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.167:MaxDepth=6:SeparationType=RegressionVariance:nCuts=36:UseRandomisedTrees=F:UseNvars=75:UseBaggedBoost=T:BaggedSampleFraction=1.233:PruneMethod=NoPruning:PruneStrength=16:PruningValFraction=0.892")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51509 -c d0starrho -p ggh
# o51510_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51510", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.088:MaxDepth=4:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=T:UseNvars=81:UseBaggedBoost=T:BaggedSampleFraction=1.763:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.674")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51510", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.088:MaxDepth=4:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=T:UseNvars=81:UseBaggedBoost=T:BaggedSampleFraction=1.763:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.674")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51510", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.088:MaxDepth=4:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=T:UseNvars=81:UseBaggedBoost=T:BaggedSampleFraction=1.763:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.674")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51510 -c d0starrho -p ggh
# o51511_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51511", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1700:BoostType=Grad:Shrinkage=0.121:MaxDepth=9:SeparationType=RegressionVariance:nCuts=43:UseRandomisedTrees=F:UseNvars=69:UseBaggedBoost=T:BaggedSampleFraction=1.905:PruneMethod=CostComplexity:PruneStrength=32:PruningValFraction=0.669")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51511", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1700:BoostType=Grad:Shrinkage=0.121:MaxDepth=9:SeparationType=RegressionVariance:nCuts=43:UseRandomisedTrees=F:UseNvars=69:UseBaggedBoost=T:BaggedSampleFraction=1.905:PruneMethod=CostComplexity:PruneStrength=32:PruningValFraction=0.669")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51511", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1700:BoostType=Grad:Shrinkage=0.121:MaxDepth=9:SeparationType=RegressionVariance:nCuts=43:UseRandomisedTrees=F:UseNvars=69:UseBaggedBoost=T:BaggedSampleFraction=1.905:PruneMethod=CostComplexity:PruneStrength=32:PruningValFraction=0.669")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51511 -c d0starrho -p ggh
# o51512_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51512", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.114:MaxDepth=5:SeparationType=RegressionVariance:nCuts=24:UseRandomisedTrees=T:UseNvars=62:UseBaggedBoost=F:BaggedSampleFraction=1.194:PruneMethod=ExpectedError:PruneStrength=44:PruningValFraction=0.476")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51512", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.114:MaxDepth=5:SeparationType=RegressionVariance:nCuts=24:UseRandomisedTrees=T:UseNvars=62:UseBaggedBoost=F:BaggedSampleFraction=1.194:PruneMethod=ExpectedError:PruneStrength=44:PruningValFraction=0.476")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51512", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.114:MaxDepth=5:SeparationType=RegressionVariance:nCuts=24:UseRandomisedTrees=T:UseNvars=62:UseBaggedBoost=F:BaggedSampleFraction=1.194:PruneMethod=ExpectedError:PruneStrength=44:PruningValFraction=0.476")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51512 -c d0starrho -p ggh
# o51513_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51513", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.131:MaxDepth=7:SeparationType=RegressionVariance:nCuts=24:UseRandomisedTrees=T:UseNvars=76:UseBaggedBoost=T:BaggedSampleFraction=1.502:PruneMethod=CostComplexity:PruneStrength=45:PruningValFraction=0.76")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51513", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.131:MaxDepth=7:SeparationType=RegressionVariance:nCuts=24:UseRandomisedTrees=T:UseNvars=76:UseBaggedBoost=T:BaggedSampleFraction=1.502:PruneMethod=CostComplexity:PruneStrength=45:PruningValFraction=0.76")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51513", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.131:MaxDepth=7:SeparationType=RegressionVariance:nCuts=24:UseRandomisedTrees=T:UseNvars=76:UseBaggedBoost=T:BaggedSampleFraction=1.502:PruneMethod=CostComplexity:PruneStrength=45:PruningValFraction=0.76")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51513 -c d0starrho -p ggh
# o51514_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51514", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=2100:BoostType=Grad:Shrinkage=0.145:MaxDepth=7:SeparationType=RegressionVariance:nCuts=25:UseRandomisedTrees=T:UseNvars=69:UseBaggedBoost=F:BaggedSampleFraction=1.427:PruneMethod=ExpectedError:PruneStrength=29:PruningValFraction=0.764")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51514", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=2100:BoostType=Grad:Shrinkage=0.145:MaxDepth=7:SeparationType=RegressionVariance:nCuts=25:UseRandomisedTrees=T:UseNvars=69:UseBaggedBoost=F:BaggedSampleFraction=1.427:PruneMethod=ExpectedError:PruneStrength=29:PruningValFraction=0.764")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51514", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=2100:BoostType=Grad:Shrinkage=0.145:MaxDepth=7:SeparationType=RegressionVariance:nCuts=25:UseRandomisedTrees=T:UseNvars=69:UseBaggedBoost=F:BaggedSampleFraction=1.427:PruneMethod=ExpectedError:PruneStrength=29:PruningValFraction=0.764")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51514 -c d0starrho -p ggh
# o51515_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51515", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,P,D:NTrees=2000:BoostType=Grad:Shrinkage=0.109:MaxDepth=4:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=T:UseNvars=53:UseBaggedBoost=T:BaggedSampleFraction=1.9:PruneMethod=ExpectedError:PruneStrength=30:PruningValFraction=0.828")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51515", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,P,D:NTrees=2000:BoostType=Grad:Shrinkage=0.109:MaxDepth=4:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=T:UseNvars=53:UseBaggedBoost=T:BaggedSampleFraction=1.9:PruneMethod=ExpectedError:PruneStrength=30:PruningValFraction=0.828")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51515", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,P,D:NTrees=2000:BoostType=Grad:Shrinkage=0.109:MaxDepth=4:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=T:UseNvars=53:UseBaggedBoost=T:BaggedSampleFraction=1.9:PruneMethod=ExpectedError:PruneStrength=30:PruningValFraction=0.828")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51515 -c d0starrho -p ggh
# o51516_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51516", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1300:BoostType=Grad:Shrinkage=0.142:MaxDepth=5:SeparationType=RegressionVariance:nCuts=31:UseRandomisedTrees=F:UseNvars=69:UseBaggedBoost=F:BaggedSampleFraction=1.476:PruneMethod=NoPruning:PruneStrength=26:PruningValFraction=0.62")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51516", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1300:BoostType=Grad:Shrinkage=0.142:MaxDepth=5:SeparationType=RegressionVariance:nCuts=31:UseRandomisedTrees=F:UseNvars=69:UseBaggedBoost=F:BaggedSampleFraction=1.476:PruneMethod=NoPruning:PruneStrength=26:PruningValFraction=0.62")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51516", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1300:BoostType=Grad:Shrinkage=0.142:MaxDepth=5:SeparationType=RegressionVariance:nCuts=31:UseRandomisedTrees=F:UseNvars=69:UseBaggedBoost=F:BaggedSampleFraction=1.476:PruneMethod=NoPruning:PruneStrength=26:PruningValFraction=0.62")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51516 -c d0starrho -p ggh
# o51517_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51517", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1500:BoostType=Grad:Shrinkage=0.103:MaxDepth=5:SeparationType=RegressionVariance:nCuts=13:UseRandomisedTrees=F:UseNvars=70:UseBaggedBoost=T:BaggedSampleFraction=1.388:PruneMethod=ExpectedError:PruneStrength=25:PruningValFraction=0.682")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51517", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1500:BoostType=Grad:Shrinkage=0.103:MaxDepth=5:SeparationType=RegressionVariance:nCuts=13:UseRandomisedTrees=F:UseNvars=70:UseBaggedBoost=T:BaggedSampleFraction=1.388:PruneMethod=ExpectedError:PruneStrength=25:PruningValFraction=0.682")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51517", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1500:BoostType=Grad:Shrinkage=0.103:MaxDepth=5:SeparationType=RegressionVariance:nCuts=13:UseRandomisedTrees=F:UseNvars=70:UseBaggedBoost=T:BaggedSampleFraction=1.388:PruneMethod=ExpectedError:PruneStrength=25:PruningValFraction=0.682")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51517 -c d0starrho -p ggh
# o51518_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51518", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=P,G:NTrees=1700:BoostType=Grad:Shrinkage=0.082:MaxDepth=6:SeparationType=RegressionVariance:nCuts=17:UseRandomisedTrees=T:UseNvars=64:UseBaggedBoost=F:BaggedSampleFraction=1.787:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.602")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51518", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=P,G:NTrees=1700:BoostType=Grad:Shrinkage=0.082:MaxDepth=6:SeparationType=RegressionVariance:nCuts=17:UseRandomisedTrees=T:UseNvars=64:UseBaggedBoost=F:BaggedSampleFraction=1.787:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.602")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51518", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=P,G:NTrees=1700:BoostType=Grad:Shrinkage=0.082:MaxDepth=6:SeparationType=RegressionVariance:nCuts=17:UseRandomisedTrees=T:UseNvars=64:UseBaggedBoost=F:BaggedSampleFraction=1.787:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.602")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51518 -c d0starrho -p ggh
# o51519_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51519", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.103:MaxDepth=6:SeparationType=RegressionVariance:nCuts=38:UseRandomisedTrees=T:UseNvars=82:UseBaggedBoost=F:BaggedSampleFraction=1.403:PruneMethod=NoPruning:PruneStrength=36:PruningValFraction=0.779")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51519", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.103:MaxDepth=6:SeparationType=RegressionVariance:nCuts=38:UseRandomisedTrees=T:UseNvars=82:UseBaggedBoost=F:BaggedSampleFraction=1.403:PruneMethod=NoPruning:PruneStrength=36:PruningValFraction=0.779")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51519", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.103:MaxDepth=6:SeparationType=RegressionVariance:nCuts=38:UseRandomisedTrees=T:UseNvars=82:UseBaggedBoost=F:BaggedSampleFraction=1.403:PruneMethod=NoPruning:PruneStrength=36:PruningValFraction=0.779")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51519 -c d0starrho -p ggh
# o51520_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51520", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=2100:BoostType=Grad:Shrinkage=0.116:MaxDepth=5:SeparationType=RegressionVariance:nCuts=35:UseRandomisedTrees=T:UseNvars=80:UseBaggedBoost=T:BaggedSampleFraction=1.525:PruneMethod=ExpectedError:PruneStrength=32:PruningValFraction=0.368")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51520", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=2100:BoostType=Grad:Shrinkage=0.116:MaxDepth=5:SeparationType=RegressionVariance:nCuts=35:UseRandomisedTrees=T:UseNvars=80:UseBaggedBoost=T:BaggedSampleFraction=1.525:PruneMethod=ExpectedError:PruneStrength=32:PruningValFraction=0.368")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51520", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=2100:BoostType=Grad:Shrinkage=0.116:MaxDepth=5:SeparationType=RegressionVariance:nCuts=35:UseRandomisedTrees=T:UseNvars=80:UseBaggedBoost=T:BaggedSampleFraction=1.525:PruneMethod=ExpectedError:PruneStrength=32:PruningValFraction=0.368")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51520 -c d0starrho -p ggh
# o51521_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51521", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=2000:BoostType=Grad:Shrinkage=0.14:MaxDepth=5:SeparationType=RegressionVariance:nCuts=18:UseRandomisedTrees=T:UseNvars=71:UseBaggedBoost=F:BaggedSampleFraction=1.439:PruneMethod=CostComplexity:PruneStrength=44:PruningValFraction=0.09")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51521", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=2000:BoostType=Grad:Shrinkage=0.14:MaxDepth=5:SeparationType=RegressionVariance:nCuts=18:UseRandomisedTrees=T:UseNvars=71:UseBaggedBoost=F:BaggedSampleFraction=1.439:PruneMethod=CostComplexity:PruneStrength=44:PruningValFraction=0.09")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51521", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=2000:BoostType=Grad:Shrinkage=0.14:MaxDepth=5:SeparationType=RegressionVariance:nCuts=18:UseRandomisedTrees=T:UseNvars=71:UseBaggedBoost=F:BaggedSampleFraction=1.439:PruneMethod=CostComplexity:PruneStrength=44:PruningValFraction=0.09")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51521 -c d0starrho -p ggh
# o51522_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51522", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.118:MaxDepth=6:SeparationType=RegressionVariance:nCuts=22:UseRandomisedTrees=F:UseNvars=62:UseBaggedBoost=T:BaggedSampleFraction=1.475:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.662")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51522", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.118:MaxDepth=6:SeparationType=RegressionVariance:nCuts=22:UseRandomisedTrees=F:UseNvars=62:UseBaggedBoost=T:BaggedSampleFraction=1.475:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.662")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51522", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.118:MaxDepth=6:SeparationType=RegressionVariance:nCuts=22:UseRandomisedTrees=F:UseNvars=62:UseBaggedBoost=T:BaggedSampleFraction=1.475:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.662")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51522 -c d0starrho -p ggh
# o51523_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51523", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.186:MaxDepth=6:SeparationType=RegressionVariance:nCuts=47:UseRandomisedTrees=T:UseNvars=76:UseBaggedBoost=T:BaggedSampleFraction=1.925:PruneMethod=NoPruning:PruneStrength=33:PruningValFraction=0.604")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51523", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.186:MaxDepth=6:SeparationType=RegressionVariance:nCuts=47:UseRandomisedTrees=T:UseNvars=76:UseBaggedBoost=T:BaggedSampleFraction=1.925:PruneMethod=NoPruning:PruneStrength=33:PruningValFraction=0.604")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51523", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.186:MaxDepth=6:SeparationType=RegressionVariance:nCuts=47:UseRandomisedTrees=T:UseNvars=76:UseBaggedBoost=T:BaggedSampleFraction=1.925:PruneMethod=NoPruning:PruneStrength=33:PruningValFraction=0.604")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51523 -c d0starrho -p ggh
# o51524_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51524", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.078:MaxDepth=5:SeparationType=RegressionVariance:nCuts=33:UseRandomisedTrees=F:UseNvars=65:UseBaggedBoost=F:BaggedSampleFraction=1.555:PruneMethod=ExpectedError:PruneStrength=35:PruningValFraction=0.667")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51524", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.078:MaxDepth=5:SeparationType=RegressionVariance:nCuts=33:UseRandomisedTrees=F:UseNvars=65:UseBaggedBoost=F:BaggedSampleFraction=1.555:PruneMethod=ExpectedError:PruneStrength=35:PruningValFraction=0.667")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51524", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.078:MaxDepth=5:SeparationType=RegressionVariance:nCuts=33:UseRandomisedTrees=F:UseNvars=65:UseBaggedBoost=F:BaggedSampleFraction=1.555:PruneMethod=ExpectedError:PruneStrength=35:PruningValFraction=0.667")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51524 -c d0starrho -p ggh
# o51525_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51525", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=2100:BoostType=Grad:Shrinkage=0.164:MaxDepth=7:SeparationType=RegressionVariance:nCuts=34:UseRandomisedTrees=F:UseNvars=70:UseBaggedBoost=T:BaggedSampleFraction=1.624:PruneMethod=NoPruning:PruneStrength=26:PruningValFraction=0.287")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51525", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=2100:BoostType=Grad:Shrinkage=0.164:MaxDepth=7:SeparationType=RegressionVariance:nCuts=34:UseRandomisedTrees=F:UseNvars=70:UseBaggedBoost=T:BaggedSampleFraction=1.624:PruneMethod=NoPruning:PruneStrength=26:PruningValFraction=0.287")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51525", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=2100:BoostType=Grad:Shrinkage=0.164:MaxDepth=7:SeparationType=RegressionVariance:nCuts=34:UseRandomisedTrees=F:UseNvars=70:UseBaggedBoost=T:BaggedSampleFraction=1.624:PruneMethod=NoPruning:PruneStrength=26:PruningValFraction=0.287")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51525 -c d0starrho -p ggh
# o51526_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51526", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.092:MaxDepth=4:SeparationType=RegressionVariance:nCuts=34:UseRandomisedTrees=T:UseNvars=76:UseBaggedBoost=T:BaggedSampleFraction=1.641:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.626")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51526", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.092:MaxDepth=4:SeparationType=RegressionVariance:nCuts=34:UseRandomisedTrees=T:UseNvars=76:UseBaggedBoost=T:BaggedSampleFraction=1.641:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.626")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51526", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.092:MaxDepth=4:SeparationType=RegressionVariance:nCuts=34:UseRandomisedTrees=T:UseNvars=76:UseBaggedBoost=T:BaggedSampleFraction=1.641:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.626")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51526 -c d0starrho -p ggh
# o51527_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51527", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=D,N,G:NTrees=1100:BoostType=Grad:Shrinkage=0.132:MaxDepth=6:SeparationType=RegressionVariance:nCuts=40:UseRandomisedTrees=F:UseNvars=75:UseBaggedBoost=T:BaggedSampleFraction=1.66:PruneMethod=NoPruning:PruneStrength=28:PruningValFraction=0.824")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51527", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=D,N,G:NTrees=1100:BoostType=Grad:Shrinkage=0.132:MaxDepth=6:SeparationType=RegressionVariance:nCuts=40:UseRandomisedTrees=F:UseNvars=75:UseBaggedBoost=T:BaggedSampleFraction=1.66:PruneMethod=NoPruning:PruneStrength=28:PruningValFraction=0.824")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51527", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=D,N,G:NTrees=1100:BoostType=Grad:Shrinkage=0.132:MaxDepth=6:SeparationType=RegressionVariance:nCuts=40:UseRandomisedTrees=F:UseNvars=75:UseBaggedBoost=T:BaggedSampleFraction=1.66:PruneMethod=NoPruning:PruneStrength=28:PruningValFraction=0.824")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51527 -c d0starrho -p ggh
# o51528_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51528", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.162:MaxDepth=4:SeparationType=RegressionVariance:nCuts=28:UseRandomisedTrees=T:UseNvars=75:UseBaggedBoost=T:BaggedSampleFraction=1.573:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.659")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51528", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.162:MaxDepth=4:SeparationType=RegressionVariance:nCuts=28:UseRandomisedTrees=T:UseNvars=75:UseBaggedBoost=T:BaggedSampleFraction=1.573:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.659")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51528", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.162:MaxDepth=4:SeparationType=RegressionVariance:nCuts=28:UseRandomisedTrees=T:UseNvars=75:UseBaggedBoost=T:BaggedSampleFraction=1.573:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.659")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51528 -c d0starrho -p ggh
# o51529_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51529", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.118:MaxDepth=6:SeparationType=RegressionVariance:nCuts=36:UseRandomisedTrees=T:UseNvars=56:UseBaggedBoost=T:BaggedSampleFraction=2.031:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.791")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51529", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.118:MaxDepth=6:SeparationType=RegressionVariance:nCuts=36:UseRandomisedTrees=T:UseNvars=56:UseBaggedBoost=T:BaggedSampleFraction=2.031:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.791")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51529", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.118:MaxDepth=6:SeparationType=RegressionVariance:nCuts=36:UseRandomisedTrees=T:UseNvars=56:UseBaggedBoost=T:BaggedSampleFraction=2.031:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.791")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51529 -c d0starrho -p ggh
# o51530_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51530", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.062:MaxDepth=7:SeparationType=RegressionVariance:nCuts=29:UseRandomisedTrees=T:UseNvars=59:UseBaggedBoost=F:BaggedSampleFraction=1.323:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.338")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51530", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.062:MaxDepth=7:SeparationType=RegressionVariance:nCuts=29:UseRandomisedTrees=T:UseNvars=59:UseBaggedBoost=F:BaggedSampleFraction=1.323:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.338")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51530", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.062:MaxDepth=7:SeparationType=RegressionVariance:nCuts=29:UseRandomisedTrees=T:UseNvars=59:UseBaggedBoost=F:BaggedSampleFraction=1.323:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.338")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51530 -c d0starrho -p ggh
# o51531_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51531", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=2200:BoostType=Grad:Shrinkage=0.121:MaxDepth=4:SeparationType=RegressionVariance:nCuts=41:UseRandomisedTrees=T:UseNvars=64:UseBaggedBoost=T:BaggedSampleFraction=1.796:PruneMethod=NoPruning:PruneStrength=37:PruningValFraction=0.629")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51531", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=2200:BoostType=Grad:Shrinkage=0.121:MaxDepth=4:SeparationType=RegressionVariance:nCuts=41:UseRandomisedTrees=T:UseNvars=64:UseBaggedBoost=T:BaggedSampleFraction=1.796:PruneMethod=NoPruning:PruneStrength=37:PruningValFraction=0.629")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51531", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=2200:BoostType=Grad:Shrinkage=0.121:MaxDepth=4:SeparationType=RegressionVariance:nCuts=41:UseRandomisedTrees=T:UseNvars=64:UseBaggedBoost=T:BaggedSampleFraction=1.796:PruneMethod=NoPruning:PruneStrength=37:PruningValFraction=0.629")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51531 -c d0starrho -p ggh
# o51532_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51532", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.113:MaxDepth=6:SeparationType=RegressionVariance:nCuts=35:UseRandomisedTrees=T:UseNvars=67:UseBaggedBoost=T:BaggedSampleFraction=1.87:PruneMethod=ExpectedError:PruneStrength=27:PruningValFraction=0.82")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51532", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.113:MaxDepth=6:SeparationType=RegressionVariance:nCuts=35:UseRandomisedTrees=T:UseNvars=67:UseBaggedBoost=T:BaggedSampleFraction=1.87:PruneMethod=ExpectedError:PruneStrength=27:PruningValFraction=0.82")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51532", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.113:MaxDepth=6:SeparationType=RegressionVariance:nCuts=35:UseRandomisedTrees=T:UseNvars=67:UseBaggedBoost=T:BaggedSampleFraction=1.87:PruneMethod=ExpectedError:PruneStrength=27:PruningValFraction=0.82")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51532 -c d0starrho -p ggh
# o51533_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51533", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=2000:BoostType=Grad:Shrinkage=0.104:MaxDepth=6:SeparationType=RegressionVariance:nCuts=24:UseRandomisedTrees=F:UseNvars=72:UseBaggedBoost=T:BaggedSampleFraction=1.38:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.633")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51533", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=2000:BoostType=Grad:Shrinkage=0.104:MaxDepth=6:SeparationType=RegressionVariance:nCuts=24:UseRandomisedTrees=F:UseNvars=72:UseBaggedBoost=T:BaggedSampleFraction=1.38:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.633")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51533", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=2000:BoostType=Grad:Shrinkage=0.104:MaxDepth=6:SeparationType=RegressionVariance:nCuts=24:UseRandomisedTrees=F:UseNvars=72:UseBaggedBoost=T:BaggedSampleFraction=1.38:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.633")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51533 -c d0starrho -p ggh
# o51534_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51534", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.123:MaxDepth=6:SeparationType=RegressionVariance:nCuts=36:UseRandomisedTrees=T:UseNvars=72:UseBaggedBoost=F:BaggedSampleFraction=1.702:PruneMethod=ExpectedError:PruneStrength=38:PruningValFraction=0.627")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51534", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.123:MaxDepth=6:SeparationType=RegressionVariance:nCuts=36:UseRandomisedTrees=T:UseNvars=72:UseBaggedBoost=F:BaggedSampleFraction=1.702:PruneMethod=ExpectedError:PruneStrength=38:PruningValFraction=0.627")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51534", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.123:MaxDepth=6:SeparationType=RegressionVariance:nCuts=36:UseRandomisedTrees=T:UseNvars=72:UseBaggedBoost=F:BaggedSampleFraction=1.702:PruneMethod=ExpectedError:PruneStrength=38:PruningValFraction=0.627")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51534 -c d0starrho -p ggh
# o51535_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51535", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.076:MaxDepth=5:SeparationType=RegressionVariance:nCuts=33:UseRandomisedTrees=T:UseNvars=68:UseBaggedBoost=T:BaggedSampleFraction=1.361:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.752")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51535", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.076:MaxDepth=5:SeparationType=RegressionVariance:nCuts=33:UseRandomisedTrees=T:UseNvars=68:UseBaggedBoost=T:BaggedSampleFraction=1.361:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.752")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51535", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.076:MaxDepth=5:SeparationType=RegressionVariance:nCuts=33:UseRandomisedTrees=T:UseNvars=68:UseBaggedBoost=T:BaggedSampleFraction=1.361:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.752")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51535 -c d0starrho -p ggh
# o51536_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51536", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1500:BoostType=Grad:Shrinkage=0.052:MaxDepth=5:SeparationType=RegressionVariance:nCuts=20:UseRandomisedTrees=T:UseNvars=70:UseBaggedBoost=T:BaggedSampleFraction=1.481:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.712")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51536", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1500:BoostType=Grad:Shrinkage=0.052:MaxDepth=5:SeparationType=RegressionVariance:nCuts=20:UseRandomisedTrees=T:UseNvars=70:UseBaggedBoost=T:BaggedSampleFraction=1.481:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.712")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51536", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1500:BoostType=Grad:Shrinkage=0.052:MaxDepth=5:SeparationType=RegressionVariance:nCuts=20:UseRandomisedTrees=T:UseNvars=70:UseBaggedBoost=T:BaggedSampleFraction=1.481:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.712")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51536 -c d0starrho -p ggh
# o51537_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51537", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=P,N,G,N:NTrees=1900:BoostType=Grad:Shrinkage=0.11:MaxDepth=4:SeparationType=RegressionVariance:nCuts=40:UseRandomisedTrees=F:UseNvars=74:UseBaggedBoost=T:BaggedSampleFraction=1.67:PruneMethod=CostComplexity:PruneStrength=40:PruningValFraction=0.845")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51537", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=P,N,G,N:NTrees=1900:BoostType=Grad:Shrinkage=0.11:MaxDepth=4:SeparationType=RegressionVariance:nCuts=40:UseRandomisedTrees=F:UseNvars=74:UseBaggedBoost=T:BaggedSampleFraction=1.67:PruneMethod=CostComplexity:PruneStrength=40:PruningValFraction=0.845")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51537", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=P,N,G,N:NTrees=1900:BoostType=Grad:Shrinkage=0.11:MaxDepth=4:SeparationType=RegressionVariance:nCuts=40:UseRandomisedTrees=F:UseNvars=74:UseBaggedBoost=T:BaggedSampleFraction=1.67:PruneMethod=CostComplexity:PruneStrength=40:PruningValFraction=0.845")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51537 -c d0starrho -p ggh
# o51538_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51538", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.068:MaxDepth=6:SeparationType=RegressionVariance:nCuts=40:UseRandomisedTrees=T:UseNvars=72:UseBaggedBoost=T:BaggedSampleFraction=1.318:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.671")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51538", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.068:MaxDepth=6:SeparationType=RegressionVariance:nCuts=40:UseRandomisedTrees=T:UseNvars=72:UseBaggedBoost=T:BaggedSampleFraction=1.318:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.671")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51538", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.068:MaxDepth=6:SeparationType=RegressionVariance:nCuts=40:UseRandomisedTrees=T:UseNvars=72:UseBaggedBoost=T:BaggedSampleFraction=1.318:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.671")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51538 -c d0starrho -p ggh
# o51539_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51539", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1200:BoostType=Grad:Shrinkage=0.128:MaxDepth=5:SeparationType=RegressionVariance:nCuts=23:UseRandomisedTrees=F:UseNvars=78:UseBaggedBoost=F:BaggedSampleFraction=1.463:PruneMethod=NoPruning:PruneStrength=30:PruningValFraction=0.392")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51539", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1200:BoostType=Grad:Shrinkage=0.128:MaxDepth=5:SeparationType=RegressionVariance:nCuts=23:UseRandomisedTrees=F:UseNvars=78:UseBaggedBoost=F:BaggedSampleFraction=1.463:PruneMethod=NoPruning:PruneStrength=30:PruningValFraction=0.392")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51539", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1200:BoostType=Grad:Shrinkage=0.128:MaxDepth=5:SeparationType=RegressionVariance:nCuts=23:UseRandomisedTrees=F:UseNvars=78:UseBaggedBoost=F:BaggedSampleFraction=1.463:PruneMethod=NoPruning:PruneStrength=30:PruningValFraction=0.392")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51539 -c d0starrho -p ggh
# ...
# o51987_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51987", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1500:BoostType=Grad:Shrinkage=0.071:MaxDepth=5:SeparationType=RegressionVariance:nCuts=45:UseRandomisedTrees=T:UseNvars=86:UseBaggedBoost=F:BaggedSampleFraction=1.471:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.732")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51987", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1500:BoostType=Grad:Shrinkage=0.071:MaxDepth=5:SeparationType=RegressionVariance:nCuts=45:UseRandomisedTrees=T:UseNvars=86:UseBaggedBoost=F:BaggedSampleFraction=1.471:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.732")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51987", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1500:BoostType=Grad:Shrinkage=0.071:MaxDepth=5:SeparationType=RegressionVariance:nCuts=45:UseRandomisedTrees=T:UseNvars=86:UseBaggedBoost=F:BaggedSampleFraction=1.471:PruneMethod=NoPruning:PruneStrength=31:PruningValFraction=0.732")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51987 -c d0starrho -p ggh
# o51988_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51988", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.121:MaxDepth=4:SeparationType=RegressionVariance:nCuts=23:UseRandomisedTrees=T:UseNvars=73:UseBaggedBoost=F:BaggedSampleFraction=1.385:PruneMethod=CostComplexity:PruneStrength=40:PruningValFraction=0.292")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51988", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.121:MaxDepth=4:SeparationType=RegressionVariance:nCuts=23:UseRandomisedTrees=T:UseNvars=73:UseBaggedBoost=F:BaggedSampleFraction=1.385:PruneMethod=CostComplexity:PruneStrength=40:PruningValFraction=0.292")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51988", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.121:MaxDepth=4:SeparationType=RegressionVariance:nCuts=23:UseRandomisedTrees=T:UseNvars=73:UseBaggedBoost=F:BaggedSampleFraction=1.385:PruneMethod=CostComplexity:PruneStrength=40:PruningValFraction=0.292")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51988 -c d0starrho -p ggh
# o51989_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51989", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G:NTrees=1100:BoostType=Grad:Shrinkage=0.163:MaxDepth=5:SeparationType=RegressionVariance:nCuts=31:UseRandomisedTrees=T:UseNvars=74:UseBaggedBoost=T:BaggedSampleFraction=1.76:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.696")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51989", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G:NTrees=1100:BoostType=Grad:Shrinkage=0.163:MaxDepth=5:SeparationType=RegressionVariance:nCuts=31:UseRandomisedTrees=T:UseNvars=74:UseBaggedBoost=T:BaggedSampleFraction=1.76:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.696")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51989", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G:NTrees=1100:BoostType=Grad:Shrinkage=0.163:MaxDepth=5:SeparationType=RegressionVariance:nCuts=31:UseRandomisedTrees=T:UseNvars=74:UseBaggedBoost=T:BaggedSampleFraction=1.76:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.696")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51989 -c d0starrho -p ggh
# o51990_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51990", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.139:MaxDepth=7:SeparationType=RegressionVariance:nCuts=20:UseRandomisedTrees=T:UseNvars=67:UseBaggedBoost=T:BaggedSampleFraction=1.365:PruneMethod=NoPruning:PruneStrength=47:PruningValFraction=0.349")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51990", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.139:MaxDepth=7:SeparationType=RegressionVariance:nCuts=20:UseRandomisedTrees=T:UseNvars=67:UseBaggedBoost=T:BaggedSampleFraction=1.365:PruneMethod=NoPruning:PruneStrength=47:PruningValFraction=0.349")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51990", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.139:MaxDepth=7:SeparationType=RegressionVariance:nCuts=20:UseRandomisedTrees=T:UseNvars=67:UseBaggedBoost=T:BaggedSampleFraction=1.365:PruneMethod=NoPruning:PruneStrength=47:PruningValFraction=0.349")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51990 -c d0starrho -p ggh
# o51991_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51991", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1700:BoostType=Grad:Shrinkage=0.17:MaxDepth=7:SeparationType=RegressionVariance:nCuts=43:UseRandomisedTrees=T:UseNvars=67:UseBaggedBoost=T:BaggedSampleFraction=1.639:PruneMethod=CostComplexity:PruneStrength=29:PruningValFraction=0.533")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51991", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1700:BoostType=Grad:Shrinkage=0.17:MaxDepth=7:SeparationType=RegressionVariance:nCuts=43:UseRandomisedTrees=T:UseNvars=67:UseBaggedBoost=T:BaggedSampleFraction=1.639:PruneMethod=CostComplexity:PruneStrength=29:PruningValFraction=0.533")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51991", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1700:BoostType=Grad:Shrinkage=0.17:MaxDepth=7:SeparationType=RegressionVariance:nCuts=43:UseRandomisedTrees=T:UseNvars=67:UseBaggedBoost=T:BaggedSampleFraction=1.639:PruneMethod=CostComplexity:PruneStrength=29:PruningValFraction=0.533")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51991 -c d0starrho -p ggh
# o51992_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51992", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.097:MaxDepth=5:SeparationType=RegressionVariance:nCuts=36:UseRandomisedTrees=T:UseNvars=71:UseBaggedBoost=F:BaggedSampleFraction=1.431:PruneMethod=NoPruning:PruneStrength=25:PruningValFraction=0.72")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51992", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.097:MaxDepth=5:SeparationType=RegressionVariance:nCuts=36:UseRandomisedTrees=T:UseNvars=71:UseBaggedBoost=F:BaggedSampleFraction=1.431:PruneMethod=NoPruning:PruneStrength=25:PruningValFraction=0.72")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51992", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.097:MaxDepth=5:SeparationType=RegressionVariance:nCuts=36:UseRandomisedTrees=T:UseNvars=71:UseBaggedBoost=F:BaggedSampleFraction=1.431:PruneMethod=NoPruning:PruneStrength=25:PruningValFraction=0.72")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51992 -c d0starrho -p ggh
# o51993_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51993", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.168:MaxDepth=5:SeparationType=RegressionVariance:nCuts=25:UseRandomisedTrees=T:UseNvars=82:UseBaggedBoost=F:BaggedSampleFraction=1.223:PruneMethod=NoPruning:PruneStrength=23:PruningValFraction=0.549")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51993", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.168:MaxDepth=5:SeparationType=RegressionVariance:nCuts=25:UseRandomisedTrees=T:UseNvars=82:UseBaggedBoost=F:BaggedSampleFraction=1.223:PruneMethod=NoPruning:PruneStrength=23:PruningValFraction=0.549")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51993", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.168:MaxDepth=5:SeparationType=RegressionVariance:nCuts=25:UseRandomisedTrees=T:UseNvars=82:UseBaggedBoost=F:BaggedSampleFraction=1.223:PruneMethod=NoPruning:PruneStrength=23:PruningValFraction=0.549")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51993 -c d0starrho -p ggh
# o51994_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51994", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.075:MaxDepth=7:SeparationType=RegressionVariance:nCuts=31:UseRandomisedTrees=T:UseNvars=62:UseBaggedBoost=T:BaggedSampleFraction=1.503:PruneMethod=ExpectedError:PruneStrength=28:PruningValFraction=0.783")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51994", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.075:MaxDepth=7:SeparationType=RegressionVariance:nCuts=31:UseRandomisedTrees=T:UseNvars=62:UseBaggedBoost=T:BaggedSampleFraction=1.503:PruneMethod=ExpectedError:PruneStrength=28:PruningValFraction=0.783")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51994", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.075:MaxDepth=7:SeparationType=RegressionVariance:nCuts=31:UseRandomisedTrees=T:UseNvars=62:UseBaggedBoost=T:BaggedSampleFraction=1.503:PruneMethod=ExpectedError:PruneStrength=28:PruningValFraction=0.783")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51994 -c d0starrho -p ggh
# o51995_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51995", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1300:BoostType=Grad:Shrinkage=0.091:MaxDepth=5:SeparationType=RegressionVariance:nCuts=33:UseRandomisedTrees=T:UseNvars=61:UseBaggedBoost=T:BaggedSampleFraction=1.461:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.538")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51995", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1300:BoostType=Grad:Shrinkage=0.091:MaxDepth=5:SeparationType=RegressionVariance:nCuts=33:UseRandomisedTrees=T:UseNvars=61:UseBaggedBoost=T:BaggedSampleFraction=1.461:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.538")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51995", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1300:BoostType=Grad:Shrinkage=0.091:MaxDepth=5:SeparationType=RegressionVariance:nCuts=33:UseRandomisedTrees=T:UseNvars=61:UseBaggedBoost=T:BaggedSampleFraction=1.461:PruneMethod=NoPruning:PruneStrength=32:PruningValFraction=0.538")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51995 -c d0starrho -p ggh
# o51996_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51996", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1500:BoostType=Grad:Shrinkage=0.116:MaxDepth=6:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=T:UseNvars=65:UseBaggedBoost=T:BaggedSampleFraction=1.789:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.816")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51996", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1500:BoostType=Grad:Shrinkage=0.116:MaxDepth=6:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=T:UseNvars=65:UseBaggedBoost=T:BaggedSampleFraction=1.789:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.816")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51996", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1500:BoostType=Grad:Shrinkage=0.116:MaxDepth=6:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=T:UseNvars=65:UseBaggedBoost=T:BaggedSampleFraction=1.789:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.816")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51996 -c d0starrho -p ggh
# o51997_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51997", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.113:MaxDepth=4:SeparationType=RegressionVariance:nCuts=30:UseRandomisedTrees=F:UseNvars=64:UseBaggedBoost=T:BaggedSampleFraction=1.557:PruneMethod=NoPruning:PruneStrength=33:PruningValFraction=0.507")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51997", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.113:MaxDepth=4:SeparationType=RegressionVariance:nCuts=30:UseRandomisedTrees=F:UseNvars=64:UseBaggedBoost=T:BaggedSampleFraction=1.557:PruneMethod=NoPruning:PruneStrength=33:PruningValFraction=0.507")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51997", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.113:MaxDepth=4:SeparationType=RegressionVariance:nCuts=30:UseRandomisedTrees=F:UseNvars=64:UseBaggedBoost=T:BaggedSampleFraction=1.557:PruneMethod=NoPruning:PruneStrength=33:PruningValFraction=0.507")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51997 -c d0starrho -p ggh
# o51998_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51998", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.129:MaxDepth=5:SeparationType=RegressionVariance:nCuts=30:UseRandomisedTrees=T:UseNvars=64:UseBaggedBoost=T:BaggedSampleFraction=1.505:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.562")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51998", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.129:MaxDepth=5:SeparationType=RegressionVariance:nCuts=30:UseRandomisedTrees=T:UseNvars=64:UseBaggedBoost=T:BaggedSampleFraction=1.505:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.562")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51998", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1900:BoostType=Grad:Shrinkage=0.129:MaxDepth=5:SeparationType=RegressionVariance:nCuts=30:UseRandomisedTrees=T:UseNvars=64:UseBaggedBoost=T:BaggedSampleFraction=1.505:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.562")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51998 -c d0starrho -p ggh
# o51999_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51999", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.155:MaxDepth=5:SeparationType=RegressionVariance:nCuts=35:UseRandomisedTrees=T:UseNvars=66:UseBaggedBoost=T:BaggedSampleFraction=1.641:PruneMethod=NoPruning:PruneStrength=21:PruningValFraction=0.719")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51999", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.155:MaxDepth=5:SeparationType=RegressionVariance:nCuts=35:UseRandomisedTrees=T:UseNvars=66:UseBaggedBoost=T:BaggedSampleFraction=1.641:PruneMethod=NoPruning:PruneStrength=21:PruningValFraction=0.719")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt51999", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1600:BoostType=Grad:Shrinkage=0.155:MaxDepth=5:SeparationType=RegressionVariance:nCuts=35:UseRandomisedTrees=T:UseNvars=66:UseBaggedBoost=T:BaggedSampleFraction=1.641:PruneMethod=NoPruning:PruneStrength=21:PruningValFraction=0.719")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt51999 -c d0starrho -p ggh

# %%
# To check the remaining models to compute
completed = []
file_path = "completedModels.txt"
with open(file_path, "r") as file:
    for line in file:
        completed.append(line.strip())
print(len(completed), completed[0])

total = []
file_path = "totalModels.txt"
with open(file_path, "r") as file:
    for line in file:
        total.append(line.strip())
print(len(total), total[0])

todo = sorted(list(set(total).difference(set(completed))))
print(len(todo))

f = open("remainingModels.txt", "w")
for line in todo:
    f.write(line + "\n")
f.close()

# %%
# To solve the errors
channel="phi"
f = open("commands_temp.txt", "w")

file_path = "errorFiles.txt"
with open(file_path, "r") as file:
    for line in file:
        jobName = line.strip().split("/")[-1][:-4]
        dfC = jobName.split("_")[0].replace("df", "")
        dlC = jobName.split("_")[1].replace("dl", "")
        listVars = [int(x.replace("v", "")) for x in jobName.split("_")[2:]]
        comm = "df{dfC}_dl{dlC}_{varNames}:root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}\", \"{channel}\", 0, {{{listVars}}}, {dfC}, {dlC})' && root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}\", \"{channel}\", 1, {{{listVars}}}, {dfC}, {dlC})' && root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}\", \"{channel}\", 2, {{{listVars}}}, {dfC}, {dlC})' && python computeErrors.py -m BDTG_df{dfC}_dl{dlC}_{varNames} -c {channel}".format(dfC=dfC, dlC=dlC, channel=channel, listVars=str(listVars)[1:-1], varNames=getVarNames(listVars))
        print(comm)
        f.write(comm + "\n")
f.close()

# %%
# To create the commands for the remaining models
channel="phi"
f = open("commands_temp.txt", "w")

file_path = "remainingModels.txt"
with open(file_path, "r") as file:
    for line in file:
        jobName = line.strip()
        dfC = jobName.split("_")[1].replace("df", "")
        dlC = jobName.split("_")[2].replace("dl", "")
        listVars = [int(x.replace("v", "")) for x in jobName.split("_")[3:]]
        comm = "df{dfC}_dl{dlC}_{varNames}:root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}\", \"{channel}\", 0, {{{listVars}}}, {dfC}, {dlC})' && root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}\", \"{channel}\", 1, {{{listVars}}}, {dfC}, {dlC})' && root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}\", \"{channel}\", 2, {{{listVars}}}, {dfC}, {dlC})' && python computeErrors.py -m BDTG_df{dfC}_dl{dlC}_{varNames} -c {channel}".format(dfC=dfC, dlC=dlC, channel=channel, listVars=str(listVars)[1:-1], varNames=getVarNames(listVars))
        print(comm)
        f.write(comm + "\n")
f.close()
