# %%
import itertools
from itertools import product
import numpy as np
import pandas as pd
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %%
def getCodeFromBinary(s):
    for i in range(len(s)):
        if s[i].isalpha():
            return getCodeFromBinary(s[:i] + '0' + s[i+1:]) + getCodeFromBinary(s[:i] + '1' + s[i+1:])
    return [int(s, 2)]

def getVarNames(listVars):
    return "_".join(["v" + str(v) for v in listVars])

# %%
def generateModelsDict(startIndex=0, numModels=10, nameOptionsFile = "/home/submit/pdmonte/CMSSW_10_6_27/src/Hrare2023/analysis/TMVA_regression/optionModels.out", centralValues=None):
    '''This function has to solve the following:
        - Create a model and append it to a dictionary
        - Save in a file the id of the model and the properties'''
    
    allModels = {}
    with open(nameOptionsFile, "a") as file:
        for i in range(numModels):
            modelOptions = getRandomOptions(centralValues=centralValues)
            allModels[startIndex + i] = getOptionsString(modelOptions)
            file.write(str(startIndex + i) + ' $ ' + ' $ '.join(modelOptions.values()) + "\n")

    return allModels
    

def getOptionsString(modelDict):
    outString = "\"!V"
    if modelDict["VarTransform"] != "":
        outString += ":VarTransform=" + modelDict["VarTransform"]
    outString += ":NTrees=" + modelDict["NTrees"]
    outString += ":BoostType=" + modelDict["BoostType"]
    outString += ":Shrinkage=" + modelDict["Shrinkage"]
    outString += ":MaxDepth=" + modelDict["MaxDepth"]
    outString += ":SeparationType=" + modelDict["SeparationType"]
    outString += ":nCuts=" + modelDict["nCuts"]
    outString += ":UseRandomisedTrees=" + modelDict["UseRandomisedTrees"]
    outString += ":UseNvars=" + modelDict["UseNvars"]
    outString += ":UseBaggedBoost=" + modelDict["UseBaggedBoost"]
    outString += ":BaggedSampleFraction=" + modelDict["BaggedSampleFraction"]
    outString += ":PruneMethod=" + modelDict["PruneMethod"]
    outString += ":PruneStrength=" + modelDict["PruneStrength"]
    outString += ":PruningValFraction=" + modelDict["PruningValFraction"]
    outString += "\""
    return outString


def getRandomOptions(centralValues=None):
    outOptions = {}
    if centralValues is None or len(centralValues) != 12:
        outOptions["VarTransform"] = getVarTransformChoice(maxSymbols=4)
        outOptions["NTrees"] = str(getRandomInt(1500, 5000))
        outOptions["BoostType"] = "Grad"
        outOptions["Shrinkage"] = str(getRandomFloat(0.10, 0.5))
        outOptions["MaxDepth"] = str(getRandomInt(5, 10))
        outOptions["SeparationType"] = "RegressionVariance"
        outOptions["nCuts"] = str(getRandomInt(15, 100))
        outOptions["UseRandomisedTrees"] = getRandomBool()
        outOptions["UseNvars"] = str(getRandomInt(2, 100))
        outOptions["UseBaggedBoost"] = getRandomBool()
        outOptions["BaggedSampleFraction"] = str(getRandomFloat(0.50, 5.00))
        outOptions["PruneMethod"] = getPruneMethodChoice()
        outOptions["PruneStrength"] = str(getRandomInt(0, 100))
        outOptions["PruningValFraction"] = str(getRandomFloat(0.0, 2.0))
    else:
        outOptions["VarTransform"] = getVarTransformChoice(maxSymbols=4, meanSigma=centralValues[0])
        outOptions["NTrees"] = str(getRandomInt(1000, 5000, meanSigma=centralValues[1], spacing=100))
        outOptions["BoostType"] = "Grad"
        outOptions["Shrinkage"] = str(getRandomFloat(0.04, 0.5, meanSigma=centralValues[2]))
        outOptions["MaxDepth"] = str(getRandomInt(4, 10, meanSigma=centralValues[3]))
        outOptions["SeparationType"] = "RegressionVariance"
        outOptions["nCuts"] = str(getRandomInt(10, 100, meanSigma=centralValues[4]))
        outOptions["UseRandomisedTrees"] = getRandomBool(meanSigma=centralValues[5])
        outOptions["UseNvars"] = str(getRandomInt(5, 100, meanSigma=centralValues[6]))
        outOptions["UseBaggedBoost"] = getRandomBool(meanSigma=centralValues[7])
        outOptions["BaggedSampleFraction"] = str(getRandomFloat(0.70, 5.00, meanSigma=centralValues[8]))
        outOptions["PruneMethod"] = getPruneMethodChoice(meanSigma=centralValues[9])
        outOptions["PruneStrength"] = str(getRandomInt(0, 100, meanSigma=centralValues[10]))
        outOptions["PruningValFraction"] = str(getRandomFloat(0.0, 2.0, meanSigma=centralValues[11]))
    return outOptions


def getVarTransformChoice(minSymbols=0, maxSymbols=2, meanSigma=None):
    # todo with sigma
    nTsf = np.random.randint(minSymbols, maxSymbols+1)
    varTransform = ["P", "G", "D", "N"]
    good = []
    initList = list(product(varTransform, repeat=nTsf))
    for e in initList:
        repeated = False
        for i in range(len(e)-1):
            if e[i] == e[i+1]:
                repeated = True
        if e.count("P") > 1:
            repeated = True
        if not repeated:
            good.append(",".join(e))
    if meanSigma is None:
        return np.random.choice(good)
    else:
        if np.random.uniform(0, 1) < meanSigma[1]:
            return meanSigma[0]
        else:
            return np.random.choice(good)


def getBestVarTransform(n=30):
    best = ["G", "N,G,N,G", "", "N", "P,N,D", "P,N,D,N", "P,G", "P,N", "P,D", "P", "N,G", "G,N", "G,N,G,N", "N,G,N", "G,N,G", "P,D,N", "P,D,N,D", "N,P,D", "N,P,N,D", "N,P,G", "P,D,G", "D,N,D", "P,G,N", "P,N,G", "D,N,G", "P,G,N,G", "D", "P,N,P,D"]
    return best[:n]


def getPruneMethodChoice(meanSigma=None):
    return "NoPruning"
    return getRandomItem(["NoPruning", "NoPruning", "ExpectedError", "CostComplexity"], meanSigma=meanSigma)


def getRandomInt(minNum = 0, maxNum=100, meanSigma=None, spacing=1):
    if meanSigma is None:
        return int(np.round(np.random.randint(minNum, maxNum+1)/spacing, 0)*spacing)
    else:
        num = np.random.normal(meanSigma[0], meanSigma[1])
        while num < minNum or num > maxNum:
            num = np.random.normal(meanSigma[0], meanSigma[1])
        return int(np.round(num/spacing, 0)*spacing)


def getRandomFloat(minNum = 0.0, maxNum=1.0, meanSigma=None):
    if meanSigma is None:
        return np.round(np.random.uniform(minNum, maxNum), 3)
    else:
        num = np.random.normal(meanSigma[0], meanSigma[1])
        while num < minNum or num > maxNum:
            num = np.random.normal(meanSigma[0], meanSigma[1])
        return np.round(num, 3)
    

def getRandomBool(meanSigma=None):
    return getRandomItem(["F", "T"], meanSigma=meanSigma)

        
def getRandomItem(listOfChoices, meanSigma=None):
    if meanSigma is None:
        return np.random.choice(listOfChoices)
    else:
        remainingChoices = [x for x in listOfChoices if x != meanSigma[0]]
        if np.random.uniform(0, 1) < meanSigma[1]:
            return meanSigma[0]
        else:
            return np.random.choice(remainingChoices)

def getInitValsModelOptions(modelsId, variances= [0.5, 600, 0.15, 2, 10, 0.7, 10, 0.7, 0.2, 0.6, 10, 0.3], fileName="/home/submit/pdmonte/CMSSW_10_6_27/src/Hrare2023/analysis/TMVA_regression/optionModels.out"):
    column_names = ['Id', 'VarTsf', 'NTrees', 'BoostType', 'Shrinkage', 'MaxDepth', 'SeparationType', 'nCuts', 'RndmTrees',
                    'UseNvars', 'UseBaggedBoost', 'BaggedSampleFraction', 'PruneMethod', 'PruneStrength', 'PruningValFraction']
    column_data_types = {'Id': int, 'VarTsf': str, 'NTrees': int, 'BoostType': str, 'Shrinkage': float, 'MaxDepth': int, 'SeparationType': str, 'nCuts': int, 'RndmTrees': str,
                    'UseNvars': int, 'UseBaggedBoost': str, 'BaggedSampleFraction': float, 'PruneMethod': str, 'PruneStrength': int, 'PruningValFraction': float}
    
    df = pd.read_csv(fileName, sep='$', names=column_names, dtype=column_data_types)
    df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
    df = df[df["Id"].isin(modelsId)]
    selected_columns = ['VarTsf', 'NTrees', 'Shrinkage', 'MaxDepth', 'nCuts', 'RndmTrees', 'UseNvars', 'UseBaggedBoost', 
                        'BaggedSampleFraction', 'PruneMethod', 'PruneStrength', 'PruningValFraction']
    list_of_lists = df[selected_columns].values.tolist()
    list_of_lists = [[[op, vr] for op, vr in zip(model, variances)] for model in list_of_lists]

    return list_of_lists

# %%
channel="phi"
channel="omega"
channel="d0star"
channel="d0starrho"
cat = "ggh"
f = open("commands_temp.txt", "a")
comm = "RECO_{channel}:::python computeErrors.py -m RECO -c {channel} -p {prodCat}".format(channel=channel, prodCat=cat)
print(comm)
f.write(comm + "\n")
dfC, dlC = 7, 3684

modelNames=["BDTG_df15_dl3684_v0_v1"] #13/3620 D3rho
#modelNames=["BDTG_df13_dl3620_v0_v1"] #13/3620 omega/phi
#modelNames=["BDTG_df7_dl3684_v0_v1"] #5/3620 D2

goodModels = [60000] #phi BDTG_df13_dl3620_v0_v1_opt50098
goodModels = [60001] #omega BDTG_df13_dl3620_v0_v1_opt50648
goodModels = [60002] #d0star BDTG_df7_dl3684_v0_v1_opt51449
goodModels = [60003] #d0starrho BDTG_df15_dl3684_v0_v1_opt51847
goodModels = [60000, 60001, 60002, 60003]

#optionsDict = {0: "\"!V:NTrees=1000:BoostType=Grad:Shrinkage=0.2:MaxDepth=5:SeparationType=SDivSqrtSPlusB:nCuts=90:UseRandomisedTrees=T:UseNvars=67:UseBaggedBoost:BaggedSampleFraction=2.4:PruneMethod=NoPruning\""}

#initVals = [["G", 0.3], [2000, 200], [0.2, 0.001], [7, 1], [30, 1], ["F", 0.37], [30, 1], ["F", 0.15], [1.0, 1], ["NoPruning", 0.677], [50, 1], [1, 1]]

initVals = getInitValsModelOptions(goodModels, variances = [0.4, 700, 0.07, 1.5, 10, 0.6, 8, 0.6, 0.25, 0.6, 8, 0.25], fileName="/home/submit/pdmonte/CMSSW_10_6_27/src/Hrare2023/analysis/TMVA_regression/optionModels.out")
#initVals = getInitValsModelOptions(goodModels, variances = [0.7, 250, 0.04, 1.1, 8, 0.7, 7, 0.7, 0.20, 0.7, 7, 0.20], fileName="/home/submit/pdmonte/CMSSW_10_6_27/src/Hrare2023/analysis/TMVA_regression/optionModels.out")
#initVals = getInitValsModelOptions(goodModels, variances = [0.9999999, 0.000001, 0.000001, 0.000001, 0.000001, 0.9999999, 0.000001, 0.9999999, 0.000001, 0.9999999, 0.000001, 0.000001], fileName="/home/submit/pdmonte/CMSSW_10_6_27/src/Hrare2023/analysis/TMVA_regression/optionModels.out")

for k, init in enumerate(initVals):
    numMod = 500
    optionsDict = generateModelsDict(startIndex=76000+k*numMod, numModels=numMod, nameOptionsFile = "/home/submit/pdmonte/CMSSW_10_6_27/src/Hrare2023/analysis/TMVA_regression/optionModels.out", centralValues=init)
    #optionsDict = generateModelsDict(startIndex=2103, numModels=1200)

    for key, v in optionsDict.items():
        for line in modelNames:
            jobName = line.strip()
            dfC = jobName.split("_")[1].replace("df", "")
            dlC = jobName.split("_")[2].replace("dl", "")
            listVars = [int(x.replace("v", "")) for x in jobName.split("_")[3:]]
            varNamesShort = "".join([str(v) for v in listVars])
            comm = "o{idx}_v{varNamesShort}_{prodCat}:::root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}_opt{idx}\", \"{channel}\", \"{prodCat}\", 0, {{{listVars}}}, {dfC}, {dlC}, {optStr})' && root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}_opt{idx}\", \"{channel}\", \"{prodCat}\", 1, {{{listVars}}}, {dfC}, {dlC}, {optStr})' && root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}_opt{idx}\", \"{channel}\", \"{prodCat}\", 2, {{{listVars}}}, {dfC}, {dlC}, {optStr})' && python computeErrors.py -m BDTG_df{dfC}_dl{dlC}_{varNames}_opt{idx} -c {channel} -p {prodCat}".format(dfC=dfC, dlC=dlC, channel=channel, prodCat=cat, listVars=str(listVars)[1:-1], varNames=getVarNames(listVars), varNamesShort=varNamesShort, idx=key, optStr=v)
            print(comm)
            f.write(comm + "\n")
f.close()
# Out:
# RECO:::python computeErrors.py -m RECO -c d0starrho -p ggh
# o76000_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76000", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1100:BoostType=Grad:Shrinkage=0.112:MaxDepth=4:SeparationType=RegressionVariance:nCuts=28:UseRandomisedTrees=F:UseNvars=78:UseBaggedBoost=T:BaggedSampleFraction=0.88:PruneMethod=NoPruning:PruneStrength=60:PruningValFraction=0.617")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76000", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1100:BoostType=Grad:Shrinkage=0.112:MaxDepth=4:SeparationType=RegressionVariance:nCuts=28:UseRandomisedTrees=F:UseNvars=78:UseBaggedBoost=T:BaggedSampleFraction=0.88:PruneMethod=NoPruning:PruneStrength=60:PruningValFraction=0.617")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76000", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1100:BoostType=Grad:Shrinkage=0.112:MaxDepth=4:SeparationType=RegressionVariance:nCuts=28:UseRandomisedTrees=F:UseNvars=78:UseBaggedBoost=T:BaggedSampleFraction=0.88:PruneMethod=NoPruning:PruneStrength=60:PruningValFraction=0.617")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76000 -c d0starrho -p ggh
# o76001_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76001", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1100:BoostType=Grad:Shrinkage=0.074:MaxDepth=5:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=T:UseNvars=81:UseBaggedBoost=T:BaggedSampleFraction=0.992:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.27")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76001", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1100:BoostType=Grad:Shrinkage=0.074:MaxDepth=5:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=T:UseNvars=81:UseBaggedBoost=T:BaggedSampleFraction=0.992:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.27")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76001", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1100:BoostType=Grad:Shrinkage=0.074:MaxDepth=5:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=T:UseNvars=81:UseBaggedBoost=T:BaggedSampleFraction=0.992:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.27")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76001 -c d0starrho -p ggh
# o76002_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76002", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=D,N,P:NTrees=1200:BoostType=Grad:Shrinkage=0.099:MaxDepth=8:SeparationType=RegressionVariance:nCuts=37:UseRandomisedTrees=F:UseNvars=75:UseBaggedBoost=F:BaggedSampleFraction=1.229:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.472")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76002", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=D,N,P:NTrees=1200:BoostType=Grad:Shrinkage=0.099:MaxDepth=8:SeparationType=RegressionVariance:nCuts=37:UseRandomisedTrees=F:UseNvars=75:UseBaggedBoost=F:BaggedSampleFraction=1.229:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.472")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76002", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=D,N,P:NTrees=1200:BoostType=Grad:Shrinkage=0.099:MaxDepth=8:SeparationType=RegressionVariance:nCuts=37:UseRandomisedTrees=F:UseNvars=75:UseBaggedBoost=F:BaggedSampleFraction=1.229:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.472")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76002 -c d0starrho -p ggh
# o76003_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76003", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=2400:BoostType=Grad:Shrinkage=0.088:MaxDepth=4:SeparationType=RegressionVariance:nCuts=49:UseRandomisedTrees=T:UseNvars=74:UseBaggedBoost=T:BaggedSampleFraction=1.314:PruneMethod=NoPruning:PruneStrength=51:PruningValFraction=0.855")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76003", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=2400:BoostType=Grad:Shrinkage=0.088:MaxDepth=4:SeparationType=RegressionVariance:nCuts=49:UseRandomisedTrees=T:UseNvars=74:UseBaggedBoost=T:BaggedSampleFraction=1.314:PruneMethod=NoPruning:PruneStrength=51:PruningValFraction=0.855")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76003", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=2400:BoostType=Grad:Shrinkage=0.088:MaxDepth=4:SeparationType=RegressionVariance:nCuts=49:UseRandomisedTrees=T:UseNvars=74:UseBaggedBoost=T:BaggedSampleFraction=1.314:PruneMethod=NoPruning:PruneStrength=51:PruningValFraction=0.855")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76003 -c d0starrho -p ggh
# o76004_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76004", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,D,P,N:NTrees=1500:BoostType=Grad:Shrinkage=0.091:MaxDepth=9:SeparationType=RegressionVariance:nCuts=55:UseRandomisedTrees=F:UseNvars=93:UseBaggedBoost=T:BaggedSampleFraction=1.034:PruneMethod=NoPruning:PruneStrength=44:PruningValFraction=0.01")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76004", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,D,P,N:NTrees=1500:BoostType=Grad:Shrinkage=0.091:MaxDepth=9:SeparationType=RegressionVariance:nCuts=55:UseRandomisedTrees=F:UseNvars=93:UseBaggedBoost=T:BaggedSampleFraction=1.034:PruneMethod=NoPruning:PruneStrength=44:PruningValFraction=0.01")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76004", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,D,P,N:NTrees=1500:BoostType=Grad:Shrinkage=0.091:MaxDepth=9:SeparationType=RegressionVariance:nCuts=55:UseRandomisedTrees=F:UseNvars=93:UseBaggedBoost=T:BaggedSampleFraction=1.034:PruneMethod=NoPruning:PruneStrength=44:PruningValFraction=0.01")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76004 -c d0starrho -p ggh
# o76005_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76005", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=D,N,P:NTrees=1900:BoostType=Grad:Shrinkage=0.219:MaxDepth=6:SeparationType=RegressionVariance:nCuts=27:UseRandomisedTrees=T:UseNvars=73:UseBaggedBoost=F:BaggedSampleFraction=1.019:PruneMethod=NoPruning:PruneStrength=50:PruningValFraction=0.507")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76005", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=D,N,P:NTrees=1900:BoostType=Grad:Shrinkage=0.219:MaxDepth=6:SeparationType=RegressionVariance:nCuts=27:UseRandomisedTrees=T:UseNvars=73:UseBaggedBoost=F:BaggedSampleFraction=1.019:PruneMethod=NoPruning:PruneStrength=50:PruningValFraction=0.507")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76005", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=D,N,P:NTrees=1900:BoostType=Grad:Shrinkage=0.219:MaxDepth=6:SeparationType=RegressionVariance:nCuts=27:UseRandomisedTrees=T:UseNvars=73:UseBaggedBoost=F:BaggedSampleFraction=1.019:PruneMethod=NoPruning:PruneStrength=50:PruningValFraction=0.507")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76005 -c d0starrho -p ggh
# o76006_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76006", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=D:NTrees=1700:BoostType=Grad:Shrinkage=0.046:MaxDepth=4:SeparationType=RegressionVariance:nCuts=50:UseRandomisedTrees=F:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=1.305:PruneMethod=NoPruning:PruneStrength=59:PruningValFraction=0.161")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76006", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=D:NTrees=1700:BoostType=Grad:Shrinkage=0.046:MaxDepth=4:SeparationType=RegressionVariance:nCuts=50:UseRandomisedTrees=F:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=1.305:PruneMethod=NoPruning:PruneStrength=59:PruningValFraction=0.161")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76006", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=D:NTrees=1700:BoostType=Grad:Shrinkage=0.046:MaxDepth=4:SeparationType=RegressionVariance:nCuts=50:UseRandomisedTrees=F:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=1.305:PruneMethod=NoPruning:PruneStrength=59:PruningValFraction=0.161")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76006 -c d0starrho -p ggh
# o76007_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76007", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.1:MaxDepth=5:SeparationType=RegressionVariance:nCuts=26:UseRandomisedTrees=T:UseNvars=69:UseBaggedBoost=F:BaggedSampleFraction=0.994:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.312")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76007", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.1:MaxDepth=5:SeparationType=RegressionVariance:nCuts=26:UseRandomisedTrees=T:UseNvars=69:UseBaggedBoost=F:BaggedSampleFraction=0.994:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.312")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76007", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.1:MaxDepth=5:SeparationType=RegressionVariance:nCuts=26:UseRandomisedTrees=T:UseNvars=69:UseBaggedBoost=F:BaggedSampleFraction=0.994:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.312")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76007 -c d0starrho -p ggh
# o76008_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76008", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1200:BoostType=Grad:Shrinkage=0.167:MaxDepth=7:SeparationType=RegressionVariance:nCuts=47:UseRandomisedTrees=F:UseNvars=70:UseBaggedBoost=F:BaggedSampleFraction=1.319:PruneMethod=NoPruning:PruneStrength=45:PruningValFraction=0.077")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76008", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1200:BoostType=Grad:Shrinkage=0.167:MaxDepth=7:SeparationType=RegressionVariance:nCuts=47:UseRandomisedTrees=F:UseNvars=70:UseBaggedBoost=F:BaggedSampleFraction=1.319:PruneMethod=NoPruning:PruneStrength=45:PruningValFraction=0.077")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76008", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1200:BoostType=Grad:Shrinkage=0.167:MaxDepth=7:SeparationType=RegressionVariance:nCuts=47:UseRandomisedTrees=F:UseNvars=70:UseBaggedBoost=F:BaggedSampleFraction=1.319:PruneMethod=NoPruning:PruneStrength=45:PruningValFraction=0.077")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76008 -c d0starrho -p ggh
# o76009_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76009", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=P,D:NTrees=2500:BoostType=Grad:Shrinkage=0.109:MaxDepth=6:SeparationType=RegressionVariance:nCuts=64:UseRandomisedTrees=F:UseNvars=75:UseBaggedBoost=T:BaggedSampleFraction=1.515:PruneMethod=NoPruning:PruneStrength=47:PruningValFraction=0.339")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76009", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=P,D:NTrees=2500:BoostType=Grad:Shrinkage=0.109:MaxDepth=6:SeparationType=RegressionVariance:nCuts=64:UseRandomisedTrees=F:UseNvars=75:UseBaggedBoost=T:BaggedSampleFraction=1.515:PruneMethod=NoPruning:PruneStrength=47:PruningValFraction=0.339")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76009", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=P,D:NTrees=2500:BoostType=Grad:Shrinkage=0.109:MaxDepth=6:SeparationType=RegressionVariance:nCuts=64:UseRandomisedTrees=F:UseNvars=75:UseBaggedBoost=T:BaggedSampleFraction=1.515:PruneMethod=NoPruning:PruneStrength=47:PruningValFraction=0.339")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76009 -c d0starrho -p ggh
# o76010_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76010", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=P,N:NTrees=1600:BoostType=Grad:Shrinkage=0.221:MaxDepth=9:SeparationType=RegressionVariance:nCuts=39:UseRandomisedTrees=T:UseNvars=63:UseBaggedBoost=T:BaggedSampleFraction=1.318:PruneMethod=NoPruning:PruneStrength=41:PruningValFraction=0.166")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76010", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=P,N:NTrees=1600:BoostType=Grad:Shrinkage=0.221:MaxDepth=9:SeparationType=RegressionVariance:nCuts=39:UseRandomisedTrees=T:UseNvars=63:UseBaggedBoost=T:BaggedSampleFraction=1.318:PruneMethod=NoPruning:PruneStrength=41:PruningValFraction=0.166")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76010", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=P,N:NTrees=1600:BoostType=Grad:Shrinkage=0.221:MaxDepth=9:SeparationType=RegressionVariance:nCuts=39:UseRandomisedTrees=T:UseNvars=63:UseBaggedBoost=T:BaggedSampleFraction=1.318:PruneMethod=NoPruning:PruneStrength=41:PruningValFraction=0.166")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76010 -c d0starrho -p ggh
# o76011_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76011", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=2300:BoostType=Grad:Shrinkage=0.119:MaxDepth=6:SeparationType=RegressionVariance:nCuts=35:UseRandomisedTrees=F:UseNvars=82:UseBaggedBoost=T:BaggedSampleFraction=1.089:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.236")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76011", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=2300:BoostType=Grad:Shrinkage=0.119:MaxDepth=6:SeparationType=RegressionVariance:nCuts=35:UseRandomisedTrees=F:UseNvars=82:UseBaggedBoost=T:BaggedSampleFraction=1.089:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.236")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76011", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=2300:BoostType=Grad:Shrinkage=0.119:MaxDepth=6:SeparationType=RegressionVariance:nCuts=35:UseRandomisedTrees=F:UseNvars=82:UseBaggedBoost=T:BaggedSampleFraction=1.089:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.236")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76011 -c d0starrho -p ggh
# o76012_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76012", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1000:BoostType=Grad:Shrinkage=0.085:MaxDepth=5:SeparationType=RegressionVariance:nCuts=56:UseRandomisedTrees=T:UseNvars=65:UseBaggedBoost=F:BaggedSampleFraction=0.899:PruneMethod=NoPruning:PruneStrength=51:PruningValFraction=0.63")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76012", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1000:BoostType=Grad:Shrinkage=0.085:MaxDepth=5:SeparationType=RegressionVariance:nCuts=56:UseRandomisedTrees=T:UseNvars=65:UseBaggedBoost=F:BaggedSampleFraction=0.899:PruneMethod=NoPruning:PruneStrength=51:PruningValFraction=0.63")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76012", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1000:BoostType=Grad:Shrinkage=0.085:MaxDepth=5:SeparationType=RegressionVariance:nCuts=56:UseRandomisedTrees=T:UseNvars=65:UseBaggedBoost=F:BaggedSampleFraction=0.899:PruneMethod=NoPruning:PruneStrength=51:PruningValFraction=0.63")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76012 -c d0starrho -p ggh
# o76013_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76013", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=P:NTrees=1700:BoostType=Grad:Shrinkage=0.052:MaxDepth=5:SeparationType=RegressionVariance:nCuts=43:UseRandomisedTrees=T:UseNvars=87:UseBaggedBoost=T:BaggedSampleFraction=1.367:PruneMethod=NoPruning:PruneStrength=54:PruningValFraction=0.56")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76013", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=P:NTrees=1700:BoostType=Grad:Shrinkage=0.052:MaxDepth=5:SeparationType=RegressionVariance:nCuts=43:UseRandomisedTrees=T:UseNvars=87:UseBaggedBoost=T:BaggedSampleFraction=1.367:PruneMethod=NoPruning:PruneStrength=54:PruningValFraction=0.56")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76013", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=P:NTrees=1700:BoostType=Grad:Shrinkage=0.052:MaxDepth=5:SeparationType=RegressionVariance:nCuts=43:UseRandomisedTrees=T:UseNvars=87:UseBaggedBoost=T:BaggedSampleFraction=1.367:PruneMethod=NoPruning:PruneStrength=54:PruningValFraction=0.56")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76013 -c d0starrho -p ggh
# o76014_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76014", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=D,G:NTrees=2500:BoostType=Grad:Shrinkage=0.075:MaxDepth=7:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=F:UseNvars=77:UseBaggedBoost=F:BaggedSampleFraction=1.035:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.359")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76014", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=D,G:NTrees=2500:BoostType=Grad:Shrinkage=0.075:MaxDepth=7:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=F:UseNvars=77:UseBaggedBoost=F:BaggedSampleFraction=1.035:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.359")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76014", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=D,G:NTrees=2500:BoostType=Grad:Shrinkage=0.075:MaxDepth=7:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=F:UseNvars=77:UseBaggedBoost=F:BaggedSampleFraction=1.035:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.359")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76014 -c d0starrho -p ggh
# o76015_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76015", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1400:BoostType=Grad:Shrinkage=0.099:MaxDepth=8:SeparationType=RegressionVariance:nCuts=33:UseRandomisedTrees=F:UseNvars=77:UseBaggedBoost=T:BaggedSampleFraction=1.651:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.191")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76015", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1400:BoostType=Grad:Shrinkage=0.099:MaxDepth=8:SeparationType=RegressionVariance:nCuts=33:UseRandomisedTrees=F:UseNvars=77:UseBaggedBoost=T:BaggedSampleFraction=1.651:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.191")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76015", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1400:BoostType=Grad:Shrinkage=0.099:MaxDepth=8:SeparationType=RegressionVariance:nCuts=33:UseRandomisedTrees=F:UseNvars=77:UseBaggedBoost=T:BaggedSampleFraction=1.651:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.191")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76015 -c d0starrho -p ggh
# o76016_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76016", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=2000:BoostType=Grad:Shrinkage=0.107:MaxDepth=8:SeparationType=RegressionVariance:nCuts=46:UseRandomisedTrees=F:UseNvars=63:UseBaggedBoost=F:BaggedSampleFraction=1.268:PruneMethod=NoPruning:PruneStrength=62:PruningValFraction=0.701")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76016", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=2000:BoostType=Grad:Shrinkage=0.107:MaxDepth=8:SeparationType=RegressionVariance:nCuts=46:UseRandomisedTrees=F:UseNvars=63:UseBaggedBoost=F:BaggedSampleFraction=1.268:PruneMethod=NoPruning:PruneStrength=62:PruningValFraction=0.701")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76016", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=2000:BoostType=Grad:Shrinkage=0.107:MaxDepth=8:SeparationType=RegressionVariance:nCuts=46:UseRandomisedTrees=F:UseNvars=63:UseBaggedBoost=F:BaggedSampleFraction=1.268:PruneMethod=NoPruning:PruneStrength=62:PruningValFraction=0.701")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76016 -c d0starrho -p ggh
# o76017_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76017", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=2000:BoostType=Grad:Shrinkage=0.123:MaxDepth=8:SeparationType=RegressionVariance:nCuts=41:UseRandomisedTrees=T:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=1.748:PruneMethod=NoPruning:PruneStrength=50:PruningValFraction=0.719")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76017", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=2000:BoostType=Grad:Shrinkage=0.123:MaxDepth=8:SeparationType=RegressionVariance:nCuts=41:UseRandomisedTrees=T:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=1.748:PruneMethod=NoPruning:PruneStrength=50:PruningValFraction=0.719")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76017", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=2000:BoostType=Grad:Shrinkage=0.123:MaxDepth=8:SeparationType=RegressionVariance:nCuts=41:UseRandomisedTrees=T:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=1.748:PruneMethod=NoPruning:PruneStrength=50:PruningValFraction=0.719")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76017 -c d0starrho -p ggh
# o76018_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76018", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=D,G:NTrees=1600:BoostType=Grad:Shrinkage=0.097:MaxDepth=6:SeparationType=RegressionVariance:nCuts=28:UseRandomisedTrees=F:UseNvars=86:UseBaggedBoost=F:BaggedSampleFraction=1.361:PruneMethod=NoPruning:PruneStrength=54:PruningValFraction=0.596")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76018", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=D,G:NTrees=1600:BoostType=Grad:Shrinkage=0.097:MaxDepth=6:SeparationType=RegressionVariance:nCuts=28:UseRandomisedTrees=F:UseNvars=86:UseBaggedBoost=F:BaggedSampleFraction=1.361:PruneMethod=NoPruning:PruneStrength=54:PruningValFraction=0.596")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76018", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=D,G:NTrees=1600:BoostType=Grad:Shrinkage=0.097:MaxDepth=6:SeparationType=RegressionVariance:nCuts=28:UseRandomisedTrees=F:UseNvars=86:UseBaggedBoost=F:BaggedSampleFraction=1.361:PruneMethod=NoPruning:PruneStrength=54:PruningValFraction=0.596")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76018 -c d0starrho -p ggh
# o76019_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76019", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G:NTrees=1100:BoostType=Grad:Shrinkage=0.061:MaxDepth=4:SeparationType=RegressionVariance:nCuts=39:UseRandomisedTrees=T:UseNvars=68:UseBaggedBoost=T:BaggedSampleFraction=1.513:PruneMethod=NoPruning:PruneStrength=38:PruningValFraction=0.322")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76019", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G:NTrees=1100:BoostType=Grad:Shrinkage=0.061:MaxDepth=4:SeparationType=RegressionVariance:nCuts=39:UseRandomisedTrees=T:UseNvars=68:UseBaggedBoost=T:BaggedSampleFraction=1.513:PruneMethod=NoPruning:PruneStrength=38:PruningValFraction=0.322")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76019", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G:NTrees=1100:BoostType=Grad:Shrinkage=0.061:MaxDepth=4:SeparationType=RegressionVariance:nCuts=39:UseRandomisedTrees=T:UseNvars=68:UseBaggedBoost=T:BaggedSampleFraction=1.513:PruneMethod=NoPruning:PruneStrength=38:PruningValFraction=0.322")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76019 -c d0starrho -p ggh
# o76020_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76020", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1000:BoostType=Grad:Shrinkage=0.085:MaxDepth=5:SeparationType=RegressionVariance:nCuts=48:UseRandomisedTrees=F:UseNvars=88:UseBaggedBoost=F:BaggedSampleFraction=1.147:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.544")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76020", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1000:BoostType=Grad:Shrinkage=0.085:MaxDepth=5:SeparationType=RegressionVariance:nCuts=48:UseRandomisedTrees=F:UseNvars=88:UseBaggedBoost=F:BaggedSampleFraction=1.147:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.544")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76020", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1000:BoostType=Grad:Shrinkage=0.085:MaxDepth=5:SeparationType=RegressionVariance:nCuts=48:UseRandomisedTrees=F:UseNvars=88:UseBaggedBoost=F:BaggedSampleFraction=1.147:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.544")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76020 -c d0starrho -p ggh
# o76021_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76021", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1500:BoostType=Grad:Shrinkage=0.115:MaxDepth=7:SeparationType=RegressionVariance:nCuts=31:UseRandomisedTrees=T:UseNvars=85:UseBaggedBoost=F:BaggedSampleFraction=1.768:PruneMethod=NoPruning:PruneStrength=45:PruningValFraction=0.48")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76021", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1500:BoostType=Grad:Shrinkage=0.115:MaxDepth=7:SeparationType=RegressionVariance:nCuts=31:UseRandomisedTrees=T:UseNvars=85:UseBaggedBoost=F:BaggedSampleFraction=1.768:PruneMethod=NoPruning:PruneStrength=45:PruningValFraction=0.48")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76021", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1500:BoostType=Grad:Shrinkage=0.115:MaxDepth=7:SeparationType=RegressionVariance:nCuts=31:UseRandomisedTrees=T:UseNvars=85:UseBaggedBoost=F:BaggedSampleFraction=1.768:PruneMethod=NoPruning:PruneStrength=45:PruningValFraction=0.48")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76021 -c d0starrho -p ggh
# o76022_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76022", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,P:NTrees=2200:BoostType=Grad:Shrinkage=0.042:MaxDepth=8:SeparationType=RegressionVariance:nCuts=39:UseRandomisedTrees=F:UseNvars=76:UseBaggedBoost=T:BaggedSampleFraction=1.698:PruneMethod=NoPruning:PruneStrength=50:PruningValFraction=0.515")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76022", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,P:NTrees=2200:BoostType=Grad:Shrinkage=0.042:MaxDepth=8:SeparationType=RegressionVariance:nCuts=39:UseRandomisedTrees=F:UseNvars=76:UseBaggedBoost=T:BaggedSampleFraction=1.698:PruneMethod=NoPruning:PruneStrength=50:PruningValFraction=0.515")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76022", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,P:NTrees=2200:BoostType=Grad:Shrinkage=0.042:MaxDepth=8:SeparationType=RegressionVariance:nCuts=39:UseRandomisedTrees=F:UseNvars=76:UseBaggedBoost=T:BaggedSampleFraction=1.698:PruneMethod=NoPruning:PruneStrength=50:PruningValFraction=0.515")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76022 -c d0starrho -p ggh
# o76023_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76023", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1800:BoostType=Grad:Shrinkage=0.157:MaxDepth=6:SeparationType=RegressionVariance:nCuts=45:UseRandomisedTrees=F:UseNvars=82:UseBaggedBoost=F:BaggedSampleFraction=1.358:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.418")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76023", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1800:BoostType=Grad:Shrinkage=0.157:MaxDepth=6:SeparationType=RegressionVariance:nCuts=45:UseRandomisedTrees=F:UseNvars=82:UseBaggedBoost=F:BaggedSampleFraction=1.358:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.418")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76023", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1800:BoostType=Grad:Shrinkage=0.157:MaxDepth=6:SeparationType=RegressionVariance:nCuts=45:UseRandomisedTrees=F:UseNvars=82:UseBaggedBoost=F:BaggedSampleFraction=1.358:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.418")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76023 -c d0starrho -p ggh
# o76024_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76024", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1500:BoostType=Grad:Shrinkage=0.137:MaxDepth=7:SeparationType=RegressionVariance:nCuts=53:UseRandomisedTrees=T:UseNvars=77:UseBaggedBoost=F:BaggedSampleFraction=1.644:PruneMethod=NoPruning:PruneStrength=58:PruningValFraction=0.239")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76024", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1500:BoostType=Grad:Shrinkage=0.137:MaxDepth=7:SeparationType=RegressionVariance:nCuts=53:UseRandomisedTrees=T:UseNvars=77:UseBaggedBoost=F:BaggedSampleFraction=1.644:PruneMethod=NoPruning:PruneStrength=58:PruningValFraction=0.239")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76024", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1500:BoostType=Grad:Shrinkage=0.137:MaxDepth=7:SeparationType=RegressionVariance:nCuts=53:UseRandomisedTrees=T:UseNvars=77:UseBaggedBoost=F:BaggedSampleFraction=1.644:PruneMethod=NoPruning:PruneStrength=58:PruningValFraction=0.239")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76024 -c d0starrho -p ggh
# o76025_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76025", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=D:NTrees=1700:BoostType=Grad:Shrinkage=0.044:MaxDepth=7:SeparationType=RegressionVariance:nCuts=35:UseRandomisedTrees=F:UseNvars=64:UseBaggedBoost=F:BaggedSampleFraction=1.176:PruneMethod=NoPruning:PruneStrength=43:PruningValFraction=0.201")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76025", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=D:NTrees=1700:BoostType=Grad:Shrinkage=0.044:MaxDepth=7:SeparationType=RegressionVariance:nCuts=35:UseRandomisedTrees=F:UseNvars=64:UseBaggedBoost=F:BaggedSampleFraction=1.176:PruneMethod=NoPruning:PruneStrength=43:PruningValFraction=0.201")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76025", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=D:NTrees=1700:BoostType=Grad:Shrinkage=0.044:MaxDepth=7:SeparationType=RegressionVariance:nCuts=35:UseRandomisedTrees=F:UseNvars=64:UseBaggedBoost=F:BaggedSampleFraction=1.176:PruneMethod=NoPruning:PruneStrength=43:PruningValFraction=0.201")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76025 -c d0starrho -p ggh
# o76026_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76026", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=P,G:NTrees=1000:BoostType=Grad:Shrinkage=0.047:MaxDepth=5:SeparationType=RegressionVariance:nCuts=46:UseRandomisedTrees=F:UseNvars=86:UseBaggedBoost=F:BaggedSampleFraction=1.036:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.795")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76026", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=P,G:NTrees=1000:BoostType=Grad:Shrinkage=0.047:MaxDepth=5:SeparationType=RegressionVariance:nCuts=46:UseRandomisedTrees=F:UseNvars=86:UseBaggedBoost=F:BaggedSampleFraction=1.036:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.795")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76026", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=P,G:NTrees=1000:BoostType=Grad:Shrinkage=0.047:MaxDepth=5:SeparationType=RegressionVariance:nCuts=46:UseRandomisedTrees=F:UseNvars=86:UseBaggedBoost=F:BaggedSampleFraction=1.036:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.795")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76026 -c d0starrho -p ggh
# o76027_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76027", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=D:NTrees=1200:BoostType=Grad:Shrinkage=0.135:MaxDepth=6:SeparationType=RegressionVariance:nCuts=46:UseRandomisedTrees=F:UseNvars=88:UseBaggedBoost=F:BaggedSampleFraction=1.058:PruneMethod=NoPruning:PruneStrength=52:PruningValFraction=0.681")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76027", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=D:NTrees=1200:BoostType=Grad:Shrinkage=0.135:MaxDepth=6:SeparationType=RegressionVariance:nCuts=46:UseRandomisedTrees=F:UseNvars=88:UseBaggedBoost=F:BaggedSampleFraction=1.058:PruneMethod=NoPruning:PruneStrength=52:PruningValFraction=0.681")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76027", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=D:NTrees=1200:BoostType=Grad:Shrinkage=0.135:MaxDepth=6:SeparationType=RegressionVariance:nCuts=46:UseRandomisedTrees=F:UseNvars=88:UseBaggedBoost=F:BaggedSampleFraction=1.058:PruneMethod=NoPruning:PruneStrength=52:PruningValFraction=0.681")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76027 -c d0starrho -p ggh
# o76028_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76028", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=N,G,N,D:NTrees=2100:BoostType=Grad:Shrinkage=0.081:MaxDepth=6:SeparationType=RegressionVariance:nCuts=38:UseRandomisedTrees=F:UseNvars=74:UseBaggedBoost=T:BaggedSampleFraction=1.394:PruneMethod=NoPruning:PruneStrength=43:PruningValFraction=0.51")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76028", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=N,G,N,D:NTrees=2100:BoostType=Grad:Shrinkage=0.081:MaxDepth=6:SeparationType=RegressionVariance:nCuts=38:UseRandomisedTrees=F:UseNvars=74:UseBaggedBoost=T:BaggedSampleFraction=1.394:PruneMethod=NoPruning:PruneStrength=43:PruningValFraction=0.51")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76028", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=N,G,N,D:NTrees=2100:BoostType=Grad:Shrinkage=0.081:MaxDepth=6:SeparationType=RegressionVariance:nCuts=38:UseRandomisedTrees=F:UseNvars=74:UseBaggedBoost=T:BaggedSampleFraction=1.394:PruneMethod=NoPruning:PruneStrength=43:PruningValFraction=0.51")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76028 -c d0starrho -p ggh
# o76029_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76029", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1200:BoostType=Grad:Shrinkage=0.061:MaxDepth=5:SeparationType=RegressionVariance:nCuts=55:UseRandomisedTrees=F:UseNvars=73:UseBaggedBoost=F:BaggedSampleFraction=1.473:PruneMethod=NoPruning:PruneStrength=65:PruningValFraction=0.404")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76029", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1200:BoostType=Grad:Shrinkage=0.061:MaxDepth=5:SeparationType=RegressionVariance:nCuts=55:UseRandomisedTrees=F:UseNvars=73:UseBaggedBoost=F:BaggedSampleFraction=1.473:PruneMethod=NoPruning:PruneStrength=65:PruningValFraction=0.404")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76029", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1200:BoostType=Grad:Shrinkage=0.061:MaxDepth=5:SeparationType=RegressionVariance:nCuts=55:UseRandomisedTrees=F:UseNvars=73:UseBaggedBoost=F:BaggedSampleFraction=1.473:PruneMethod=NoPruning:PruneStrength=65:PruningValFraction=0.404")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76029 -c d0starrho -p ggh
# o76030_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76030", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1500:BoostType=Grad:Shrinkage=0.066:MaxDepth=9:SeparationType=RegressionVariance:nCuts=36:UseRandomisedTrees=T:UseNvars=66:UseBaggedBoost=F:BaggedSampleFraction=1.226:PruneMethod=NoPruning:PruneStrength=54:PruningValFraction=0.725")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76030", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1500:BoostType=Grad:Shrinkage=0.066:MaxDepth=9:SeparationType=RegressionVariance:nCuts=36:UseRandomisedTrees=T:UseNvars=66:UseBaggedBoost=F:BaggedSampleFraction=1.226:PruneMethod=NoPruning:PruneStrength=54:PruningValFraction=0.725")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76030", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1500:BoostType=Grad:Shrinkage=0.066:MaxDepth=9:SeparationType=RegressionVariance:nCuts=36:UseRandomisedTrees=T:UseNvars=66:UseBaggedBoost=F:BaggedSampleFraction=1.226:PruneMethod=NoPruning:PruneStrength=54:PruningValFraction=0.725")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76030 -c d0starrho -p ggh
# o76031_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76031", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,D,G:NTrees=1000:BoostType=Grad:Shrinkage=0.153:MaxDepth=7:SeparationType=RegressionVariance:nCuts=56:UseRandomisedTrees=T:UseNvars=72:UseBaggedBoost=T:BaggedSampleFraction=1.721:PruneMethod=NoPruning:PruneStrength=48:PruningValFraction=0.498")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76031", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,D,G:NTrees=1000:BoostType=Grad:Shrinkage=0.153:MaxDepth=7:SeparationType=RegressionVariance:nCuts=56:UseRandomisedTrees=T:UseNvars=72:UseBaggedBoost=T:BaggedSampleFraction=1.721:PruneMethod=NoPruning:PruneStrength=48:PruningValFraction=0.498")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76031", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,D,G:NTrees=1000:BoostType=Grad:Shrinkage=0.153:MaxDepth=7:SeparationType=RegressionVariance:nCuts=56:UseRandomisedTrees=T:UseNvars=72:UseBaggedBoost=T:BaggedSampleFraction=1.721:PruneMethod=NoPruning:PruneStrength=48:PruningValFraction=0.498")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76031 -c d0starrho -p ggh
# o76032_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76032", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1700:BoostType=Grad:Shrinkage=0.101:MaxDepth=5:SeparationType=RegressionVariance:nCuts=26:UseRandomisedTrees=T:UseNvars=89:UseBaggedBoost=T:BaggedSampleFraction=1.365:PruneMethod=NoPruning:PruneStrength=57:PruningValFraction=0.659")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76032", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1700:BoostType=Grad:Shrinkage=0.101:MaxDepth=5:SeparationType=RegressionVariance:nCuts=26:UseRandomisedTrees=T:UseNvars=89:UseBaggedBoost=T:BaggedSampleFraction=1.365:PruneMethod=NoPruning:PruneStrength=57:PruningValFraction=0.659")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76032", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1700:BoostType=Grad:Shrinkage=0.101:MaxDepth=5:SeparationType=RegressionVariance:nCuts=26:UseRandomisedTrees=T:UseNvars=89:UseBaggedBoost=T:BaggedSampleFraction=1.365:PruneMethod=NoPruning:PruneStrength=57:PruningValFraction=0.659")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76032 -c d0starrho -p ggh
# o76033_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76033", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1700:BoostType=Grad:Shrinkage=0.044:MaxDepth=5:SeparationType=RegressionVariance:nCuts=42:UseRandomisedTrees=T:UseNvars=71:UseBaggedBoost=F:BaggedSampleFraction=0.895:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.927")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76033", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1700:BoostType=Grad:Shrinkage=0.044:MaxDepth=5:SeparationType=RegressionVariance:nCuts=42:UseRandomisedTrees=T:UseNvars=71:UseBaggedBoost=F:BaggedSampleFraction=0.895:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.927")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76033", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1700:BoostType=Grad:Shrinkage=0.044:MaxDepth=5:SeparationType=RegressionVariance:nCuts=42:UseRandomisedTrees=T:UseNvars=71:UseBaggedBoost=F:BaggedSampleFraction=0.895:PruneMethod=NoPruning:PruneStrength=49:PruningValFraction=0.927")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76033 -c d0starrho -p ggh
# o76034_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76034", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.102:MaxDepth=7:SeparationType=RegressionVariance:nCuts=41:UseRandomisedTrees=T:UseNvars=70:UseBaggedBoost=F:BaggedSampleFraction=1.247:PruneMethod=NoPruning:PruneStrength=51:PruningValFraction=0.348")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76034", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.102:MaxDepth=7:SeparationType=RegressionVariance:nCuts=41:UseRandomisedTrees=T:UseNvars=70:UseBaggedBoost=F:BaggedSampleFraction=1.247:PruneMethod=NoPruning:PruneStrength=51:PruningValFraction=0.348")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76034", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.102:MaxDepth=7:SeparationType=RegressionVariance:nCuts=41:UseRandomisedTrees=T:UseNvars=70:UseBaggedBoost=F:BaggedSampleFraction=1.247:PruneMethod=NoPruning:PruneStrength=51:PruningValFraction=0.348")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76034 -c d0starrho -p ggh
# o76035_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76035", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,P,D,G:NTrees=1200:BoostType=Grad:Shrinkage=0.106:MaxDepth=6:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=F:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=1.082:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.52")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76035", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,P,D,G:NTrees=1200:BoostType=Grad:Shrinkage=0.106:MaxDepth=6:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=F:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=1.082:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.52")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76035", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,P,D,G:NTrees=1200:BoostType=Grad:Shrinkage=0.106:MaxDepth=6:SeparationType=RegressionVariance:nCuts=32:UseRandomisedTrees=F:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=1.082:PruneMethod=NoPruning:PruneStrength=34:PruningValFraction=0.52")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76035 -c d0starrho -p ggh
# o76036_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76036", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.126:MaxDepth=7:SeparationType=RegressionVariance:nCuts=38:UseRandomisedTrees=F:UseNvars=71:UseBaggedBoost=T:BaggedSampleFraction=0.926:PruneMethod=NoPruning:PruneStrength=56:PruningValFraction=0.472")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76036", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.126:MaxDepth=7:SeparationType=RegressionVariance:nCuts=38:UseRandomisedTrees=F:UseNvars=71:UseBaggedBoost=T:BaggedSampleFraction=0.926:PruneMethod=NoPruning:PruneStrength=56:PruningValFraction=0.472")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76036", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1400:BoostType=Grad:Shrinkage=0.126:MaxDepth=7:SeparationType=RegressionVariance:nCuts=38:UseRandomisedTrees=F:UseNvars=71:UseBaggedBoost=T:BaggedSampleFraction=0.926:PruneMethod=NoPruning:PruneStrength=56:PruningValFraction=0.472")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76036 -c d0starrho -p ggh
# o76037_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76037", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1200:BoostType=Grad:Shrinkage=0.197:MaxDepth=5:SeparationType=RegressionVariance:nCuts=37:UseRandomisedTrees=T:UseNvars=75:UseBaggedBoost=F:BaggedSampleFraction=1.553:PruneMethod=NoPruning:PruneStrength=37:PruningValFraction=0.495")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76037", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1200:BoostType=Grad:Shrinkage=0.197:MaxDepth=5:SeparationType=RegressionVariance:nCuts=37:UseRandomisedTrees=T:UseNvars=75:UseBaggedBoost=F:BaggedSampleFraction=1.553:PruneMethod=NoPruning:PruneStrength=37:PruningValFraction=0.495")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76037", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,N,P:NTrees=1200:BoostType=Grad:Shrinkage=0.197:MaxDepth=5:SeparationType=RegressionVariance:nCuts=37:UseRandomisedTrees=T:UseNvars=75:UseBaggedBoost=F:BaggedSampleFraction=1.553:PruneMethod=NoPruning:PruneStrength=37:PruningValFraction=0.495")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76037 -c d0starrho -p ggh
# o76038_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76038", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,D,N,G:NTrees=1600:BoostType=Grad:Shrinkage=0.111:MaxDepth=5:SeparationType=RegressionVariance:nCuts=44:UseRandomisedTrees=F:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=1.308:PruneMethod=NoPruning:PruneStrength=43:PruningValFraction=0.55")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76038", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,D,N,G:NTrees=1600:BoostType=Grad:Shrinkage=0.111:MaxDepth=5:SeparationType=RegressionVariance:nCuts=44:UseRandomisedTrees=F:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=1.308:PruneMethod=NoPruning:PruneStrength=43:PruningValFraction=0.55")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt76038", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,D,N,G:NTrees=1600:BoostType=Grad:Shrinkage=0.111:MaxDepth=5:SeparationType=RegressionVariance:nCuts=44:UseRandomisedTrees=F:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=1.308:PruneMethod=NoPruning:PruneStrength=43:PruningValFraction=0.55")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt76038 -c d0starrho -p ggh
# ...
# o77987_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77987", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=P,G,N:NTrees=2500:BoostType=Grad:Shrinkage=0.08:MaxDepth=4:SeparationType=RegressionVariance:nCuts=19:UseRandomisedTrees=T:UseNvars=63:UseBaggedBoost=F:BaggedSampleFraction=1.554:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.502")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77987", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=P,G,N:NTrees=2500:BoostType=Grad:Shrinkage=0.08:MaxDepth=4:SeparationType=RegressionVariance:nCuts=19:UseRandomisedTrees=T:UseNvars=63:UseBaggedBoost=F:BaggedSampleFraction=1.554:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.502")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77987", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=P,G,N:NTrees=2500:BoostType=Grad:Shrinkage=0.08:MaxDepth=4:SeparationType=RegressionVariance:nCuts=19:UseRandomisedTrees=T:UseNvars=63:UseBaggedBoost=F:BaggedSampleFraction=1.554:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.502")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt77987 -c d0starrho -p ggh
# o77988_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77988", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=P,N,D,N:NTrees=1400:BoostType=Grad:Shrinkage=0.088:MaxDepth=8:SeparationType=RegressionVariance:nCuts=43:UseRandomisedTrees=T:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=1.851:PruneMethod=NoPruning:PruneStrength=43:PruningValFraction=1.085")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77988", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=P,N,D,N:NTrees=1400:BoostType=Grad:Shrinkage=0.088:MaxDepth=8:SeparationType=RegressionVariance:nCuts=43:UseRandomisedTrees=T:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=1.851:PruneMethod=NoPruning:PruneStrength=43:PruningValFraction=1.085")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77988", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=P,N,D,N:NTrees=1400:BoostType=Grad:Shrinkage=0.088:MaxDepth=8:SeparationType=RegressionVariance:nCuts=43:UseRandomisedTrees=T:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=1.851:PruneMethod=NoPruning:PruneStrength=43:PruningValFraction=1.085")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt77988 -c d0starrho -p ggh
# o77989_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77989", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=P,G,D,G:NTrees=2100:BoostType=Grad:Shrinkage=0.108:MaxDepth=8:SeparationType=RegressionVariance:nCuts=29:UseRandomisedTrees=T:UseNvars=83:UseBaggedBoost=T:BaggedSampleFraction=1.829:PruneMethod=NoPruning:PruneStrength=29:PruningValFraction=0.681")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77989", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=P,G,D,G:NTrees=2100:BoostType=Grad:Shrinkage=0.108:MaxDepth=8:SeparationType=RegressionVariance:nCuts=29:UseRandomisedTrees=T:UseNvars=83:UseBaggedBoost=T:BaggedSampleFraction=1.829:PruneMethod=NoPruning:PruneStrength=29:PruningValFraction=0.681")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77989", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=P,G,D,G:NTrees=2100:BoostType=Grad:Shrinkage=0.108:MaxDepth=8:SeparationType=RegressionVariance:nCuts=29:UseRandomisedTrees=T:UseNvars=83:UseBaggedBoost=T:BaggedSampleFraction=1.829:PruneMethod=NoPruning:PruneStrength=29:PruningValFraction=0.681")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt77989 -c d0starrho -p ggh
# o77990_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77990", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=N,P,D,N:NTrees=2700:BoostType=Grad:Shrinkage=0.113:MaxDepth=6:SeparationType=RegressionVariance:nCuts=29:UseRandomisedTrees=F:UseNvars=68:UseBaggedBoost=T:BaggedSampleFraction=1.65:PruneMethod=NoPruning:PruneStrength=48:PruningValFraction=0.48")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77990", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=N,P,D,N:NTrees=2700:BoostType=Grad:Shrinkage=0.113:MaxDepth=6:SeparationType=RegressionVariance:nCuts=29:UseRandomisedTrees=F:UseNvars=68:UseBaggedBoost=T:BaggedSampleFraction=1.65:PruneMethod=NoPruning:PruneStrength=48:PruningValFraction=0.48")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77990", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=N,P,D,N:NTrees=2700:BoostType=Grad:Shrinkage=0.113:MaxDepth=6:SeparationType=RegressionVariance:nCuts=29:UseRandomisedTrees=F:UseNvars=68:UseBaggedBoost=T:BaggedSampleFraction=1.65:PruneMethod=NoPruning:PruneStrength=48:PruningValFraction=0.48")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt77990 -c d0starrho -p ggh
# o77991_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77991", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=D,P:NTrees=1900:BoostType=Grad:Shrinkage=0.081:MaxDepth=5:SeparationType=RegressionVariance:nCuts=23:UseRandomisedTrees=F:UseNvars=73:UseBaggedBoost=F:BaggedSampleFraction=1.52:PruneMethod=NoPruning:PruneStrength=35:PruningValFraction=0.279")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77991", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=D,P:NTrees=1900:BoostType=Grad:Shrinkage=0.081:MaxDepth=5:SeparationType=RegressionVariance:nCuts=23:UseRandomisedTrees=F:UseNvars=73:UseBaggedBoost=F:BaggedSampleFraction=1.52:PruneMethod=NoPruning:PruneStrength=35:PruningValFraction=0.279")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77991", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=D,P:NTrees=1900:BoostType=Grad:Shrinkage=0.081:MaxDepth=5:SeparationType=RegressionVariance:nCuts=23:UseRandomisedTrees=F:UseNvars=73:UseBaggedBoost=F:BaggedSampleFraction=1.52:PruneMethod=NoPruning:PruneStrength=35:PruningValFraction=0.279")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt77991 -c d0starrho -p ggh
# o77992_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77992", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=P:NTrees=1500:BoostType=Grad:Shrinkage=0.057:MaxDepth=5:SeparationType=RegressionVariance:nCuts=46:UseRandomisedTrees=T:UseNvars=65:UseBaggedBoost=T:BaggedSampleFraction=1.626:PruneMethod=NoPruning:PruneStrength=36:PruningValFraction=0.864")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77992", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=P:NTrees=1500:BoostType=Grad:Shrinkage=0.057:MaxDepth=5:SeparationType=RegressionVariance:nCuts=46:UseRandomisedTrees=T:UseNvars=65:UseBaggedBoost=T:BaggedSampleFraction=1.626:PruneMethod=NoPruning:PruneStrength=36:PruningValFraction=0.864")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77992", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=P:NTrees=1500:BoostType=Grad:Shrinkage=0.057:MaxDepth=5:SeparationType=RegressionVariance:nCuts=46:UseRandomisedTrees=T:UseNvars=65:UseBaggedBoost=T:BaggedSampleFraction=1.626:PruneMethod=NoPruning:PruneStrength=36:PruningValFraction=0.864")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt77992 -c d0starrho -p ggh
# o77993_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77993", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=2300:BoostType=Grad:Shrinkage=0.176:MaxDepth=5:SeparationType=RegressionVariance:nCuts=38:UseRandomisedTrees=T:UseNvars=81:UseBaggedBoost=T:BaggedSampleFraction=1.768:PruneMethod=NoPruning:PruneStrength=24:PruningValFraction=0.386")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77993", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=2300:BoostType=Grad:Shrinkage=0.176:MaxDepth=5:SeparationType=RegressionVariance:nCuts=38:UseRandomisedTrees=T:UseNvars=81:UseBaggedBoost=T:BaggedSampleFraction=1.768:PruneMethod=NoPruning:PruneStrength=24:PruningValFraction=0.386")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77993", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=2300:BoostType=Grad:Shrinkage=0.176:MaxDepth=5:SeparationType=RegressionVariance:nCuts=38:UseRandomisedTrees=T:UseNvars=81:UseBaggedBoost=T:BaggedSampleFraction=1.768:PruneMethod=NoPruning:PruneStrength=24:PruningValFraction=0.386")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt77993 -c d0starrho -p ggh
# o77994_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77994", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=2400:BoostType=Grad:Shrinkage=0.061:MaxDepth=6:SeparationType=RegressionVariance:nCuts=34:UseRandomisedTrees=F:UseNvars=63:UseBaggedBoost=F:BaggedSampleFraction=1.627:PruneMethod=NoPruning:PruneStrength=24:PruningValFraction=0.307")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77994", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=2400:BoostType=Grad:Shrinkage=0.061:MaxDepth=6:SeparationType=RegressionVariance:nCuts=34:UseRandomisedTrees=F:UseNvars=63:UseBaggedBoost=F:BaggedSampleFraction=1.627:PruneMethod=NoPruning:PruneStrength=24:PruningValFraction=0.307")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77994", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=2400:BoostType=Grad:Shrinkage=0.061:MaxDepth=6:SeparationType=RegressionVariance:nCuts=34:UseRandomisedTrees=F:UseNvars=63:UseBaggedBoost=F:BaggedSampleFraction=1.627:PruneMethod=NoPruning:PruneStrength=24:PruningValFraction=0.307")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt77994 -c d0starrho -p ggh
# o77995_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77995", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=P,D,G,D:NTrees=1800:BoostType=Grad:Shrinkage=0.154:MaxDepth=6:SeparationType=RegressionVariance:nCuts=17:UseRandomisedTrees=T:UseNvars=67:UseBaggedBoost=T:BaggedSampleFraction=1.63:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.175")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77995", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=P,D,G,D:NTrees=1800:BoostType=Grad:Shrinkage=0.154:MaxDepth=6:SeparationType=RegressionVariance:nCuts=17:UseRandomisedTrees=T:UseNvars=67:UseBaggedBoost=T:BaggedSampleFraction=1.63:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.175")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77995", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=P,D,G,D:NTrees=1800:BoostType=Grad:Shrinkage=0.154:MaxDepth=6:SeparationType=RegressionVariance:nCuts=17:UseRandomisedTrees=T:UseNvars=67:UseBaggedBoost=T:BaggedSampleFraction=1.63:PruneMethod=NoPruning:PruneStrength=39:PruningValFraction=0.175")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt77995 -c d0starrho -p ggh
# o77996_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77996", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.192:MaxDepth=5:SeparationType=RegressionVariance:nCuts=42:UseRandomisedTrees=T:UseNvars=76:UseBaggedBoost=F:BaggedSampleFraction=1.444:PruneMethod=NoPruning:PruneStrength=41:PruningValFraction=0.227")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77996", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.192:MaxDepth=5:SeparationType=RegressionVariance:nCuts=42:UseRandomisedTrees=T:UseNvars=76:UseBaggedBoost=F:BaggedSampleFraction=1.444:PruneMethod=NoPruning:PruneStrength=41:PruningValFraction=0.227")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77996", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1800:BoostType=Grad:Shrinkage=0.192:MaxDepth=5:SeparationType=RegressionVariance:nCuts=42:UseRandomisedTrees=T:UseNvars=76:UseBaggedBoost=F:BaggedSampleFraction=1.444:PruneMethod=NoPruning:PruneStrength=41:PruningValFraction=0.227")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt77996 -c d0starrho -p ggh
# o77997_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77997", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:NTrees=1100:BoostType=Grad:Shrinkage=0.046:MaxDepth=6:SeparationType=RegressionVariance:nCuts=28:UseRandomisedTrees=T:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=0.928:PruneMethod=NoPruning:PruneStrength=21:PruningValFraction=0.54")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77997", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:NTrees=1100:BoostType=Grad:Shrinkage=0.046:MaxDepth=6:SeparationType=RegressionVariance:nCuts=28:UseRandomisedTrees=T:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=0.928:PruneMethod=NoPruning:PruneStrength=21:PruningValFraction=0.54")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77997", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:NTrees=1100:BoostType=Grad:Shrinkage=0.046:MaxDepth=6:SeparationType=RegressionVariance:nCuts=28:UseRandomisedTrees=T:UseNvars=68:UseBaggedBoost=F:BaggedSampleFraction=0.928:PruneMethod=NoPruning:PruneStrength=21:PruningValFraction=0.54")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt77997 -c d0starrho -p ggh
# o77998_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77998", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=N,P,G,N:NTrees=2100:BoostType=Grad:Shrinkage=0.108:MaxDepth=6:SeparationType=RegressionVariance:nCuts=49:UseRandomisedTrees=T:UseNvars=72:UseBaggedBoost=T:BaggedSampleFraction=1.942:PruneMethod=NoPruning:PruneStrength=54:PruningValFraction=0.6")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77998", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=N,P,G,N:NTrees=2100:BoostType=Grad:Shrinkage=0.108:MaxDepth=6:SeparationType=RegressionVariance:nCuts=49:UseRandomisedTrees=T:UseNvars=72:UseBaggedBoost=T:BaggedSampleFraction=1.942:PruneMethod=NoPruning:PruneStrength=54:PruningValFraction=0.6")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77998", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=N,P,G,N:NTrees=2100:BoostType=Grad:Shrinkage=0.108:MaxDepth=6:SeparationType=RegressionVariance:nCuts=49:UseRandomisedTrees=T:UseNvars=72:UseBaggedBoost=T:BaggedSampleFraction=1.942:PruneMethod=NoPruning:PruneStrength=54:PruningValFraction=0.6")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt77998 -c d0starrho -p ggh
# o77999_v01_ggh:::root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77999", "d0starrho", "ggh", 0, {0, 1}, 15, 3684, "!V:VarTransform=G,P,G:NTrees=1000:BoostType=Grad:Shrinkage=0.14:MaxDepth=5:SeparationType=RegressionVariance:nCuts=25:UseRandomisedTrees=T:UseNvars=65:UseBaggedBoost=F:BaggedSampleFraction=1.122:PruneMethod=NoPruning:PruneStrength=33:PruningValFraction=0.743")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77999", "d0starrho", "ggh", 1, {0, 1}, 15, 3684, "!V:VarTransform=G,P,G:NTrees=1000:BoostType=Grad:Shrinkage=0.14:MaxDepth=5:SeparationType=RegressionVariance:nCuts=25:UseRandomisedTrees=T:UseNvars=65:UseBaggedBoost=F:BaggedSampleFraction=1.122:PruneMethod=NoPruning:PruneStrength=33:PruningValFraction=0.743")' && root -l -q -b 'TMVA_GF_regression.C("BDTG_df15_dl3684_v0_v1_opt77999", "d0starrho", "ggh", 2, {0, 1}, 15, 3684, "!V:VarTransform=G,P,G:NTrees=1000:BoostType=Grad:Shrinkage=0.14:MaxDepth=5:SeparationType=RegressionVariance:nCuts=25:UseRandomisedTrees=T:UseNvars=65:UseBaggedBoost=F:BaggedSampleFraction=1.122:PruneMethod=NoPruning:PruneStrength=33:PruningValFraction=0.743")' && python computeErrors.py -m BDTG_df15_dl3684_v0_v1_opt77999 -c d0starrho -p ggh

# %%
# To check the remaining models to compute
completed = []
file_path = "completedModels.txt"
with open(file_path, "r") as file:
    for line in file:
        completed.append(line.strip())
print(len(completed), completed[0])

total = []
file_path = "totalModels.txt"
with open(file_path, "r") as file:
    for line in file:
        total.append(line.strip())
print(len(total), total[0])

todo = sorted(list(set(total).difference(set(completed))))
print(len(todo))

f = open("remainingModels.txt", "w")
for line in todo:
    f.write(line + "\n")
f.close()

# %%
# To solve the errors
channel="phi"
f = open("commands_temp.txt", "w")

file_path = "errorFiles.txt"
with open(file_path, "r") as file:
    for line in file:
        jobName = line.strip().split("/")[-1][:-4]
        dfC = jobName.split("_")[0].replace("df", "")
        dlC = jobName.split("_")[1].replace("dl", "")
        listVars = [int(x.replace("v", "")) for x in jobName.split("_")[2:]]
        comm = "df{dfC}_dl{dlC}_{varNames}:root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}\", \"{channel}\", 0, {{{listVars}}}, {dfC}, {dlC})' && root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}\", \"{channel}\", 1, {{{listVars}}}, {dfC}, {dlC})' && root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}\", \"{channel}\", 2, {{{listVars}}}, {dfC}, {dlC})' && python computeErrors.py -m BDTG_df{dfC}_dl{dlC}_{varNames} -c {channel}".format(dfC=dfC, dlC=dlC, channel=channel, listVars=str(listVars)[1:-1], varNames=getVarNames(listVars))
        print(comm)
        f.write(comm + "\n")
f.close()

# %%
# To create the commands for the remaining models
channel="phi"
f = open("commands_temp.txt", "w")

file_path = "remainingModels.txt"
with open(file_path, "r") as file:
    for line in file:
        jobName = line.strip()
        dfC = jobName.split("_")[1].replace("df", "")
        dlC = jobName.split("_")[2].replace("dl", "")
        listVars = [int(x.replace("v", "")) for x in jobName.split("_")[3:]]
        comm = "df{dfC}_dl{dlC}_{varNames}:root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}\", \"{channel}\", 0, {{{listVars}}}, {dfC}, {dlC})' && root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}\", \"{channel}\", 1, {{{listVars}}}, {dfC}, {dlC})' && root -l -q -b 'TMVA_GF_regression.C(\"BDTG_df{dfC}_dl{dlC}_{varNames}\", \"{channel}\", 2, {{{listVars}}}, {dfC}, {dlC})' && python computeErrors.py -m BDTG_df{dfC}_dl{dlC}_{varNames} -c {channel}".format(dfC=dfC, dlC=dlC, channel=channel, listVars=str(listVars)[1:-1], varNames=getVarNames(listVars))
        print(comm)
        f.write(comm + "\n")
f.close()
